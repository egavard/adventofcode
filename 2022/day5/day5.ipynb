# %% [markdown]
# ### Day 5: Supply Stacks
# The expedition can depart as soon as the final supplies have been unloaded from the ships. Supplies are stored in stacks of marked crates, but because the needed supplies are buried under many other crates, the crates need to be rearranged.
#
# The ship has a giant cargo crane capable of moving crates between stacks. To ensure none of the crates get crushed or fall over, the crane operator will rearrange them in a series of carefully-planned steps. After the crates are rearranged, the desired crates will be at the top of each stack.
#
# The Elves don't want to interrupt the crane operator during this delicate procedure, but they forgot to ask her which crate will end up where, and they want to be ready to unload them as soon as possible so they can embark.
#
# They do, however, have a drawing of the starting stacks of crates and the rearrangement procedure (your puzzle input). For example:
#
# ```
#     [D]
# [N] [C]
# [Z] [M] [P]
#  1   2   3
#
# move 1 from 2 to 1
# move 3 from 1 to 3
# move 2 from 2 to 1
# move 1 from 1 to 2
# ```
#
# In this example, there are three stacks of crates. Stack `1` contains two crates: crate `Z` is on the bottom, and crate `N` is on top. Stack `2` contains three crates; from bottom to top, they are crates `M`, `C`, and `D`. Finally, stack `3` contains a single crate, `P`.
#
# Then, the rearrangement procedure is given. In each step of the procedure, a quantity of crates is moved from one stack to a different stack. In the first step of the above rearrangement procedure, one crate is moved from stack `2` to stack `1`, resulting in this configuration:
# ```
# [D]
# [N] [C]
# [Z] [M] [P]
#  1   2   3
# ```
#
# In the second step, three crates are moved from stack `1` to stack `3`. Crates are moved one at a time, so the first crate to be moved (`D`) ends up below the second and third crates:
# ```
#         [Z]
#         [N]
#     [C] [D]
#     [M] [P]
#  1   2   3
# ```
#
# Then, both crates are moved from stack `2` to stack `1`. Again, because crates are moved one at a time, crate `C` ends up below crate `M`:
#
# ```
#         [Z]
#         [N]
# [M]     [D]
# [C]     [P]
#  1   2   3
# ```
#
# Finally, one crate is moved from stack `1` to stack `2`:
#
# ```
#         [Z]
#         [N]
#         [D]
# [C] [M] [P]
#  1   2   3
# ```
#
# The Elves just need to know which crate will end up on top of each stack; in this example, the top crates are `C` in stack `1`, `M` in stack `2`, and `Z` in stack `3`, so you should combine these together and give the Elves the message `CMZ`.
#
# After the rearrangement procedure completes, what crate ends up on top of each stack?
#
# Your puzzle answer was `JDTMRWCQJ`.

# %%
from collections import deque


def append_to_stack_not_empty(char, stack):
    if len(char.strip()) > 0:
        stack.appendleft(char)


def retrieve_line_entries(line_, stack_1, stack_2, stack_3, stack_4, stack_5, stack_6, stack_7, stack_8, stack_9):
    line_ = line_.strip()
    append_to_stack_not_empty(line_[1], stack_1)
    append_to_stack_not_empty(line_[5], stack_2)
    append_to_stack_not_empty(line_[9], stack_3)
    append_to_stack_not_empty(line_[13], stack_4)
    append_to_stack_not_empty(line_[17], stack_5)
    append_to_stack_not_empty(line_[21], stack_6)
    if len(line_) > 24:
        append_to_stack_not_empty(line_[25], stack_7)
    if len(line_) > 29:
        append_to_stack_not_empty(line_[29], stack_8)
    if len(line_) > 32:
        append_to_stack_not_empty(line_[33], stack_9)


def move_stack(line_, stacks):
    splitted = line_.split(" ")
    qty = int(splitted[1])
    frm_number = int(splitted[3])
    to_number = int(splitted[5])
    frm: deque = stacks[frm_number - 1]
    to: deque = stacks[to_number - 1]

    for i in range(0, qty):
        to.append(frm.pop())


with open("day5.txt") as file_content:
    stack1 = deque()
    stack2 = deque()
    stack3 = deque()
    stack4 = deque()
    stack5 = deque()
    stack6 = deque()
    stack7 = deque()
    stack8 = deque()
    stack9 = deque()
    cpt = 0
    for line in file_content:
        if cpt <= 7:
            retrieve_line_entries(line, stack1, stack2, stack3, stack4, stack5, stack6, stack7, stack8, stack9)
            # stack ready
        if cpt >= 10:
            move_stack(line, [stack1, stack2, stack3, stack4, stack5, stack6, stack7, stack8, stack9])
        cpt += 1

    print(stack1.pop(),stack2.pop(),stack3.pop(),stack4.pop(), stack5.pop(), stack6.pop(), stack7.pop(), stack8.pop(), stack9.pop(),sep="")
# Out:
# deque(['D', 'R', 'V', 'Z', 'G', 'V', 'V', 'B', 'D', 'P', 'S', 'H', 'L', 'R', 'R', 'V', 'J'])
# deque(['H', 'L', 'Q', 'P', 'H', 'Q', 'D'])
# deque(['F', 'V', 'N', 'N', 'Z', 'T'])
# deque(['M'])
# deque(['M', 'G', 'P', 'R'])
# deque(['W'])
# deque(['L', 'C'])
# deque(['Q'])
# deque(['W', 'J', 'C', 'W', 'F', 'R', 'B', 'V', 'J', 'Z', 'L', 'C', 'B', 'D', 'D', 'P', 'J'])
# JDTMRWCQJ

# %% [markdown]
# ### Part Two
# As you watch the crane operator expertly rearrange the crates, you notice the process isn't following your prediction.
#
# Some mud was covering the writing on the side of the crane, and you quickly wipe it away. The crane isn't a CrateMover 9000 - it's a CrateMover 9001.
#
# The CrateMover 9001 is notable for many new and exciting features: air conditioning, leather seats, an extra cup holder, and the ability to pick up and move multiple crates at once.
#
# Again considering the example above, the crates begin in the same configuration:
# ```
#     [D]
# [N] [C]
# [Z] [M] [P]
#  1   2   3
# ```
#
# Moving a single crate from stack `2` to stack `1` behaves the same as before:
#
# ```
# [D]
# [N] [C]
# [Z] [M] [P]
#  1   2   3
# ```
# However, the action of moving three crates from stack `1` to stack `3` means that those three moved crates stay in the same order, resulting in this new configuration:
#
# ```
#         [D]
#         [N]
#     [C] [Z]
#     [M] [P]
#  1   2   3
# ```
#
# Next, as both crates are moved from stack `2` to stack `1`, they retain their order as well:
#
# ```
#         [D]
#         [N]
# [C]     [Z]
# [M]     [P]
#  1   2   3
# ```
#
# Finally, a single crate is still moved from stack `1` to stack `2`, but now it's crate `C` that gets moved:
#
# ```
#         [D]
#         [N]
#         [Z]
# [M] [C] [P]
#  1   2   3
# ```
#
# In this example, the CrateMover 9001 has put the crates in a totally different order: `MCD`.
#
# Before the rearrangement process finishes, update your simulation so that the Elves know where they should stand to be ready to unload the final supplies. After the rearrangement procedure completes, what crate ends up on top of each stack?

# %%
from collections import deque


def append_to_stack_not_empty(char, stack):
    if len(char.strip()) > 0:
        stack.appendleft(char)


def retrieve_line_entries(line_, stack_1, stack_2, stack_3, stack_4, stack_5, stack_6, stack_7, stack_8, stack_9):
    line_ = line_.strip()
    append_to_stack_not_empty(line_[1], stack_1)
    append_to_stack_not_empty(line_[5], stack_2)
    append_to_stack_not_empty(line_[9], stack_3)
    append_to_stack_not_empty(line_[13], stack_4)
    append_to_stack_not_empty(line_[17], stack_5)
    append_to_stack_not_empty(line_[21], stack_6)
    if len(line_) > 24:
        append_to_stack_not_empty(line_[25], stack_7)
    if len(line_) > 29:
        append_to_stack_not_empty(line_[29], stack_8)
    if len(line_) > 32:
        append_to_stack_not_empty(line_[33], stack_9)


def move_stack(line_, stacks):
    splitted = line_.split(" ")
    qty = int(splitted[1])
    frm_number = int(splitted[3])
    to_number = int(splitted[5])
    frm: deque = stacks[frm_number - 1]
    to: deque = stacks[to_number - 1]
    temp_queue = deque()

    for i in range(0, qty):
        temp_queue.append(frm.pop())
    for i in range(0, qty):
        to.append(temp_queue.pop())


with open("day5.txt") as file_content:
    stack1 = deque()
    stack2 = deque()
    stack3 = deque()
    stack4 = deque()
    stack5 = deque()
    stack6 = deque()
    stack7 = deque()
    stack8 = deque()
    stack9 = deque()
    cpt = 0
    for line in file_content:
        if cpt <= 7:
            retrieve_line_entries(line, stack1, stack2, stack3, stack4, stack5, stack6, stack7, stack8, stack9)
            # stack ready
        if cpt >= 10:
            move_stack(line, [stack1, stack2, stack3, stack4, stack5, stack6, stack7, stack8, stack9])
        cpt += 1

    print(stack1.pop(),stack2.pop(),stack3.pop(),stack4.pop(), stack5.pop(), stack6.pop(), stack7.pop(), stack8.pop(), stack9.pop(),sep="")
# Out:
# deque(['D', 'C', 'N', 'W', 'V']) deque(['F', 'H', 'B', 'V', 'R', 'Q', 'D', 'P']) 4
# deque(['D']) deque(['F', 'H', 'B', 'V', 'R', 'Q', 'D', 'P', 'C', 'N', 'W', 'V']) 4
# deque(['H', 'L', 'Z', 'Q', 'G', 'R', 'P', 'C']) deque(['F', 'H', 'B', 'V', 'R', 'Q', 'D', 'P', 'C', 'N', 'W', 'V']) 6
# deque(['H', 'L']) deque(['F', 'H', 'B', 'V', 'R', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'Z', 'Q', 'G', 'R', 'P', 'C']) 6
# deque(['R', 'D', 'H', 'F', 'J', 'V', 'B']) deque(['F', 'H', 'B', 'V', 'R', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'Z', 'Q', 'G', 'R', 'P', 'C']) 7
# deque([]) deque(['F', 'H', 'B', 'V', 'R', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'Z', 'Q', 'G', 'R', 'P', 'C', 'R', 'D', 'H', 'F', 'J', 'V', 'B']) 7
# deque(['D', 'P', 'J']) deque(['Z', 'W', 'L', 'C']) 2
# deque(['D']) deque(['Z', 'W', 'L', 'C', 'P', 'J']) 2
# deque(['D']) deque(['J', 'R', 'L', 'V', 'M', 'B', 'S']) 1
# deque([]) deque(['J', 'R', 'L', 'V', 'M', 'B', 'S', 'D']) 1
# deque(['D']) deque(['Z', 'W', 'L', 'C', 'P', 'J']) 1
# deque([]) deque(['Z', 'W', 'L', 'C', 'P', 'J', 'D']) 1
# deque(['J', 'R', 'P', 'N', 'T', 'G', 'V', 'M']) deque([]) 3
# deque(['J', 'R', 'P', 'N', 'T']) deque(['G', 'V', 'M']) 3
# deque(['F', 'H', 'B', 'V', 'R', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'Z', 'Q', 'G', 'R', 'P', 'C', 'R', 'D', 'H', 'F', 'J', 'V', 'B']) deque(['Z', 'W', 'L', 'C', 'P', 'J', 'D']) 6
# deque(['F', 'H', 'B', 'V', 'R', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'Z', 'Q', 'G', 'R', 'P', 'C', 'R']) deque(['Z', 'W', 'L', 'C', 'P', 'J', 'D', 'D', 'H', 'F', 'J', 'V', 'B']) 6
# deque(['F', 'H', 'B', 'V', 'R', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'Z', 'Q', 'G', 'R', 'P', 'C', 'R']) deque(['L', 'D', 'Z', 'Q', 'W', 'V']) 14
# deque(['F', 'H', 'B', 'V', 'R']) deque(['L', 'D', 'Z', 'Q', 'W', 'V', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'Z', 'Q', 'G', 'R', 'P', 'C', 'R']) 14
# deque(['J', 'R', 'P', 'N', 'T']) deque(['F', 'H', 'B', 'V', 'R']) 1
# deque(['J', 'R', 'P', 'N']) deque(['F', 'H', 'B', 'V', 'R', 'T']) 1
# deque(['J', 'R', 'P', 'N']) deque(['L', 'D', 'Z', 'Q', 'W', 'V', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'Z', 'Q', 'G', 'R', 'P', 'C', 'R']) 2
# deque(['J', 'R']) deque(['L', 'D', 'Z', 'Q', 'W', 'V', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'Z', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N']) 2
# deque(['Z', 'W', 'L', 'C', 'P', 'J', 'D', 'D', 'H', 'F', 'J', 'V', 'B']) deque([]) 9
# deque(['Z', 'W', 'L', 'C']) deque(['P', 'J', 'D', 'D', 'H', 'F', 'J', 'V', 'B']) 9
# deque(['G', 'V', 'M']) deque(['Z', 'W', 'L', 'C']) 2
# deque(['G']) deque(['Z', 'W', 'L', 'C', 'V', 'M']) 2
# deque(['Z', 'W', 'L', 'C', 'V', 'M']) deque(['H', 'L']) 2
# deque(['Z', 'W', 'L', 'C']) deque(['H', 'L', 'V', 'M']) 2
# deque(['P', 'J', 'D', 'D', 'H', 'F', 'J', 'V', 'B']) deque(['J', 'R']) 6
# deque(['P', 'J', 'D']) deque(['J', 'R', 'D', 'H', 'F', 'J', 'V', 'B']) 6
# deque(['F', 'H', 'B', 'V', 'R', 'T']) deque(['L', 'D', 'Z', 'Q', 'W', 'V', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'Z', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N']) 4
# deque(['F', 'H']) deque(['L', 'D', 'Z', 'Q', 'W', 'V', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'Z', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B', 'V', 'R', 'T']) 4
# deque(['F', 'H']) deque(['L', 'D', 'Z', 'Q', 'W', 'V', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'Z', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B', 'V', 'R', 'T']) 2
# deque([]) deque(['L', 'D', 'Z', 'Q', 'W', 'V', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'Z', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B', 'V', 'R', 'T', 'F', 'H']) 2
# deque(['J', 'R', 'D', 'H', 'F', 'J', 'V', 'B']) deque([]) 5
# deque(['J', 'R', 'D']) deque(['H', 'F', 'J', 'V', 'B']) 5
# deque(['G']) deque(['P', 'J', 'D']) 1
# deque([]) deque(['P', 'J', 'D', 'G']) 1
# deque(['P', 'J', 'D', 'G']) deque([]) 4
# deque([]) deque(['P', 'J', 'D', 'G']) 4
# deque(['H', 'L', 'V', 'M']) deque(['J', 'R', 'L', 'V', 'M', 'B', 'S', 'D']) 2
# deque(['H', 'L']) deque(['J', 'R', 'L', 'V', 'M', 'B', 'S', 'D', 'V', 'M']) 2
# deque(['P', 'J', 'D', 'G']) deque([]) 2
# deque(['P', 'J']) deque(['D', 'G']) 2
# deque(['D', 'G']) deque(['J', 'R', 'D']) 2
# deque([]) deque(['J', 'R', 'D', 'D', 'G']) 2
# deque(['L', 'D', 'Z', 'Q', 'W', 'V', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'Z', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B', 'V', 'R', 'T', 'F', 'H']) deque([]) 5
# deque(['L', 'D', 'Z', 'Q', 'W', 'V', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'Z', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B']) deque(['V', 'R', 'T', 'F', 'H']) 5
# deque(['P', 'J']) deque(['V', 'R', 'T', 'F', 'H']) 1
# deque(['P']) deque(['V', 'R', 'T', 'F', 'H', 'J']) 1
# deque(['P']) deque(['H', 'L']) 1
# deque([]) deque(['H', 'L', 'P']) 1
# deque(['V', 'R', 'T', 'F', 'H', 'J']) deque([]) 5
# deque(['V']) deque(['R', 'T', 'F', 'H', 'J']) 5
# deque(['J', 'R', 'D', 'D', 'G']) deque(['Z', 'W', 'L', 'C']) 1
# deque(['J', 'R', 'D', 'D']) deque(['Z', 'W', 'L', 'C', 'G']) 1
# deque(['J', 'R', 'L', 'V', 'M', 'B', 'S', 'D', 'V', 'M']) deque(['Z', 'W', 'L', 'C', 'G']) 3
# deque(['J', 'R', 'L', 'V', 'M', 'B', 'S']) deque(['Z', 'W', 'L', 'C', 'G', 'D', 'V', 'M']) 3
# deque(['H', 'F', 'J', 'V', 'B']) deque(['J', 'R', 'D', 'D']) 2
# deque(['H', 'F', 'J']) deque(['J', 'R', 'D', 'D', 'V', 'B']) 2
# deque(['J', 'R', 'D', 'D', 'V', 'B']) deque(['R', 'T', 'F', 'H', 'J']) 5
# deque(['J']) deque(['R', 'T', 'F', 'H', 'J', 'R', 'D', 'D', 'V', 'B']) 5
# deque(['V']) deque([]) 1
# deque([]) deque(['V']) 1
# deque(['J']) deque(['Z', 'W', 'L', 'C', 'G', 'D', 'V', 'M']) 1
# deque([]) deque(['Z', 'W', 'L', 'C', 'G', 'D', 'V', 'M', 'J']) 1
# deque(['L', 'D', 'Z', 'Q', 'W', 'V', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'Z', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B']) deque(['J', 'R', 'L', 'V', 'M', 'B', 'S']) 9
# deque(['L', 'D', 'Z', 'Q', 'W', 'V', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'Z']) deque(['J', 'R', 'L', 'V', 'M', 'B', 'S', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B']) 9
# deque(['L', 'D', 'Z', 'Q', 'W', 'V', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'Z']) deque(['H', 'L', 'P']) 1
# deque(['L', 'D', 'Z', 'Q', 'W', 'V', 'Q', 'D', 'P', 'C', 'N', 'W', 'V']) deque(['H', 'L', 'P', 'Z']) 1
# deque(['V']) deque([]) 1
# deque([]) deque(['V']) 1
# deque(['Z', 'W', 'L', 'C', 'G', 'D', 'V', 'M', 'J']) deque([]) 8
# deque(['Z']) deque(['W', 'L', 'C', 'G', 'D', 'V', 'M', 'J']) 8
# deque(['V']) deque(['H', 'F', 'J']) 1
# deque([]) deque(['H', 'F', 'J', 'V']) 1
# deque(['R', 'T', 'F', 'H', 'J', 'R', 'D', 'D', 'V', 'B']) deque([]) 2
# deque(['R', 'T', 'F', 'H', 'J', 'R', 'D', 'D']) deque(['V', 'B']) 2
# deque(['V', 'B']) deque(['W', 'L', 'C', 'G', 'D', 'V', 'M', 'J']) 1
# deque(['V']) deque(['W', 'L', 'C', 'G', 'D', 'V', 'M', 'J', 'B']) 1
# deque(['W', 'L', 'C', 'G', 'D', 'V', 'M', 'J', 'B']) deque(['V']) 7
# deque(['W', 'L']) deque(['V', 'C', 'G', 'D', 'V', 'M', 'J', 'B']) 7
# deque(['H', 'L', 'P', 'Z']) deque(['H', 'F', 'J', 'V']) 1
# deque(['H', 'L', 'P']) deque(['H', 'F', 'J', 'V', 'Z']) 1
# deque(['H', 'L', 'P']) deque(['W', 'L']) 1
# deque(['H', 'L']) deque(['W', 'L', 'P']) 1
# deque(['W', 'L', 'P']) deque(['H', 'F', 'J', 'V', 'Z']) 3
# deque([]) deque(['H', 'F', 'J', 'V', 'Z', 'W', 'L', 'P']) 3
# deque(['H', 'L']) deque([]) 2
# deque([]) deque(['H', 'L']) 2
# deque(['H', 'L']) deque(['Z']) 2
# deque([]) deque(['Z', 'H', 'L']) 2
# deque(['Z', 'H', 'L']) deque(['J', 'R', 'L', 'V', 'M', 'B', 'S', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B']) 3
# deque([]) deque(['J', 'R', 'L', 'V', 'M', 'B', 'S', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B', 'Z', 'H', 'L']) 3
# deque(['R', 'T', 'F', 'H', 'J', 'R', 'D', 'D']) deque(['L', 'D', 'Z', 'Q', 'W', 'V', 'Q', 'D', 'P', 'C', 'N', 'W', 'V']) 7
# deque(['R']) deque(['L', 'D', 'Z', 'Q', 'W', 'V', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'T', 'F', 'H', 'J', 'R', 'D', 'D']) 7
# deque(['H', 'F', 'J', 'V', 'Z', 'W', 'L', 'P']) deque(['L', 'D', 'Z', 'Q', 'W', 'V', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'T', 'F', 'H', 'J', 'R', 'D', 'D']) 5
# deque(['H', 'F', 'J']) deque(['L', 'D', 'Z', 'Q', 'W', 'V', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'T', 'F', 'H', 'J', 'R', 'D', 'D', 'V', 'Z', 'W', 'L', 'P']) 5
# deque(['J', 'R', 'L', 'V', 'M', 'B', 'S', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B', 'Z', 'H', 'L']) deque(['V', 'C', 'G', 'D', 'V', 'M', 'J', 'B']) 12
# deque(['J', 'R', 'L', 'V', 'M', 'B', 'S']) deque(['V', 'C', 'G', 'D', 'V', 'M', 'J', 'B', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B', 'Z', 'H', 'L']) 12
# deque(['H', 'F', 'J']) deque([]) 2
# deque(['H']) deque(['F', 'J']) 2
# deque(['F', 'J']) deque(['H']) 2
# deque([]) deque(['H', 'F', 'J']) 2
# deque(['J', 'R', 'L', 'V', 'M', 'B', 'S']) deque([]) 1
# deque(['J', 'R', 'L', 'V', 'M', 'B']) deque(['S']) 1
# deque(['L', 'D', 'Z', 'Q', 'W', 'V', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'T', 'F', 'H', 'J', 'R', 'D', 'D', 'V', 'Z', 'W', 'L', 'P']) deque([]) 6
# deque(['L', 'D', 'Z', 'Q', 'W', 'V', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'T', 'F', 'H', 'J', 'R', 'D']) deque(['D', 'V', 'Z', 'W', 'L', 'P']) 6
# deque(['L', 'D', 'Z', 'Q', 'W', 'V', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'T', 'F', 'H', 'J', 'R', 'D']) deque(['V', 'C', 'G', 'D', 'V', 'M', 'J', 'B', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B', 'Z', 'H', 'L']) 5
# deque(['L', 'D', 'Z', 'Q', 'W', 'V', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'T']) deque(['V', 'C', 'G', 'D', 'V', 'M', 'J', 'B', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B', 'Z', 'H', 'L', 'F', 'H', 'J', 'R', 'D']) 5
# deque(['L', 'D', 'Z', 'Q', 'W', 'V', 'Q', 'D', 'P', 'C', 'N', 'W', 'V', 'T']) deque(['V', 'C', 'G', 'D', 'V', 'M', 'J', 'B', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B', 'Z', 'H', 'L', 'F', 'H', 'J', 'R', 'D']) 6
# deque(['L', 'D', 'Z', 'Q', 'W', 'V', 'Q', 'D']) deque(['V', 'C', 'G', 'D', 'V', 'M', 'J', 'B', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B', 'Z', 'H', 'L', 'F', 'H', 'J', 'R', 'D', 'P', 'C', 'N', 'W', 'V', 'T']) 6
# deque(['D', 'V', 'Z', 'W', 'L', 'P']) deque(['H', 'F', 'J']) 4
# deque(['D', 'V']) deque(['H', 'F', 'J', 'Z', 'W', 'L', 'P']) 4
# deque(['L', 'D', 'Z', 'Q', 'W', 'V', 'Q', 'D']) deque(['H', 'F', 'J', 'Z', 'W', 'L', 'P']) 3
# deque(['L', 'D', 'Z', 'Q', 'W']) deque(['H', 'F', 'J', 'Z', 'W', 'L', 'P', 'V', 'Q', 'D']) 3
# deque(['S']) deque([]) 1
# deque([]) deque(['S']) 1
# deque(['H', 'F', 'J', 'Z', 'W', 'L', 'P', 'V', 'Q', 'D']) deque(['L', 'D', 'Z', 'Q', 'W']) 7
# deque(['H', 'F', 'J']) deque(['L', 'D', 'Z', 'Q', 'W', 'Z', 'W', 'L', 'P', 'V', 'Q', 'D']) 7
# deque(['S']) deque(['R']) 1
# deque([]) deque(['R', 'S']) 1
# deque(['L', 'D', 'Z', 'Q', 'W', 'Z', 'W', 'L', 'P', 'V', 'Q', 'D']) deque([]) 7
# deque(['L', 'D', 'Z', 'Q', 'W']) deque(['Z', 'W', 'L', 'P', 'V', 'Q', 'D']) 7
# deque(['L', 'D', 'Z', 'Q', 'W']) deque(['R', 'S']) 5
# deque([]) deque(['R', 'S', 'L', 'D', 'Z', 'Q', 'W']) 5
# deque(['V', 'C', 'G', 'D', 'V', 'M', 'J', 'B', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B', 'Z', 'H', 'L', 'F', 'H', 'J', 'R', 'D', 'P', 'C', 'N', 'W', 'V', 'T']) deque(['R', 'S', 'L', 'D', 'Z', 'Q', 'W']) 2
# deque(['V', 'C', 'G', 'D', 'V', 'M', 'J', 'B', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B', 'Z', 'H', 'L', 'F', 'H', 'J', 'R', 'D', 'P', 'C', 'N', 'W']) deque(['R', 'S', 'L', 'D', 'Z', 'Q', 'W', 'V', 'T']) 2
# deque(['V', 'C', 'G', 'D', 'V', 'M', 'J', 'B', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B', 'Z', 'H', 'L', 'F', 'H', 'J', 'R', 'D', 'P', 'C', 'N', 'W']) deque(['Z', 'W', 'L', 'P', 'V', 'Q', 'D']) 21
# deque(['V', 'C', 'G', 'D', 'V', 'M', 'J', 'B']) deque(['Z', 'W', 'L', 'P', 'V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B', 'Z', 'H', 'L', 'F', 'H', 'J', 'R', 'D', 'P', 'C', 'N', 'W']) 21
# deque(['Z', 'W', 'L', 'P', 'V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B', 'Z', 'H', 'L', 'F', 'H', 'J', 'R', 'D', 'P', 'C', 'N', 'W']) deque(['H', 'F', 'J']) 8
# deque(['Z', 'W', 'L', 'P', 'V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B', 'Z', 'H', 'L', 'F']) deque(['H', 'F', 'J', 'H', 'J', 'R', 'D', 'P', 'C', 'N', 'W']) 8
# deque(['V', 'C', 'G', 'D', 'V', 'M', 'J', 'B']) deque(['H', 'F', 'J', 'H', 'J', 'R', 'D', 'P', 'C', 'N', 'W']) 2
# deque(['V', 'C', 'G', 'D', 'V', 'M']) deque(['H', 'F', 'J', 'H', 'J', 'R', 'D', 'P', 'C', 'N', 'W', 'J', 'B']) 2
# deque(['R', 'S', 'L', 'D', 'Z', 'Q', 'W', 'V', 'T']) deque(['J', 'R', 'L', 'V', 'M', 'B']) 3
# deque(['R', 'S', 'L', 'D', 'Z', 'Q']) deque(['J', 'R', 'L', 'V', 'M', 'B', 'W', 'V', 'T']) 3
# deque(['V', 'C', 'G', 'D', 'V', 'M']) deque([]) 6
# deque([]) deque(['V', 'C', 'G', 'D', 'V', 'M']) 6
# deque(['H', 'F', 'J', 'H', 'J', 'R', 'D', 'P', 'C', 'N', 'W', 'J', 'B']) deque(['R', 'S', 'L', 'D', 'Z', 'Q']) 7
# deque(['H', 'F', 'J', 'H', 'J', 'R']) deque(['R', 'S', 'L', 'D', 'Z', 'Q', 'D', 'P', 'C', 'N', 'W', 'J', 'B']) 7
# deque(['Z', 'W', 'L', 'P', 'V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B', 'Z', 'H', 'L', 'F']) deque(['H', 'F', 'J', 'H', 'J', 'R']) 1
# deque(['Z', 'W', 'L', 'P', 'V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B', 'Z', 'H', 'L']) deque(['H', 'F', 'J', 'H', 'J', 'R', 'F']) 1
# deque(['J', 'R', 'L', 'V', 'M', 'B', 'W', 'V', 'T']) deque(['D', 'V']) 7
# deque(['J', 'R']) deque(['D', 'V', 'L', 'V', 'M', 'B', 'W', 'V', 'T']) 7
# deque(['J', 'R']) deque(['V', 'C', 'G', 'D', 'V', 'M']) 1
# deque(['J']) deque(['V', 'C', 'G', 'D', 'V', 'M', 'R']) 1
# deque(['J']) deque(['V', 'C', 'G', 'D', 'V', 'M', 'R']) 1
# deque([]) deque(['V', 'C', 'G', 'D', 'V', 'M', 'R', 'J']) 1
# deque(['R', 'S', 'L', 'D', 'Z', 'Q', 'D', 'P', 'C', 'N', 'W', 'J', 'B']) deque(['H', 'F', 'J', 'H', 'J', 'R', 'F']) 7
# deque(['R', 'S', 'L', 'D', 'Z', 'Q']) deque(['H', 'F', 'J', 'H', 'J', 'R', 'F', 'D', 'P', 'C', 'N', 'W', 'J', 'B']) 7
# deque(['V', 'C', 'G', 'D', 'V', 'M', 'R', 'J']) deque(['R', 'S', 'L', 'D', 'Z', 'Q']) 5
# deque(['V', 'C', 'G']) deque(['R', 'S', 'L', 'D', 'Z', 'Q', 'D', 'V', 'M', 'R', 'J']) 5
# deque(['H', 'F', 'J', 'H', 'J', 'R', 'F', 'D', 'P', 'C', 'N', 'W', 'J', 'B']) deque([]) 10
# deque(['H', 'F', 'J', 'H']) deque(['J', 'R', 'F', 'D', 'P', 'C', 'N', 'W', 'J', 'B']) 10
# deque(['H', 'F', 'J', 'H']) deque(['V', 'C', 'G']) 3
# deque(['H']) deque(['V', 'C', 'G', 'F', 'J', 'H']) 3
# deque(['J', 'R', 'F', 'D', 'P', 'C', 'N', 'W', 'J', 'B']) deque(['Z', 'W', 'L', 'P', 'V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B', 'Z', 'H', 'L']) 3
# deque(['J', 'R', 'F', 'D', 'P', 'C', 'N']) deque(['Z', 'W', 'L', 'P', 'V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B', 'Z', 'H', 'L', 'W', 'J', 'B']) 3
# deque(['V', 'C', 'G', 'F', 'J', 'H']) deque([]) 1
# deque(['V', 'C', 'G', 'F', 'J']) deque(['H']) 1
# deque(['D', 'V', 'L', 'V', 'M', 'B', 'W', 'V', 'T']) deque([]) 3
# deque(['D', 'V', 'L', 'V', 'M', 'B']) deque(['W', 'V', 'T']) 3
# deque(['W', 'V', 'T']) deque(['V', 'C', 'G', 'F', 'J']) 1
# deque(['W', 'V']) deque(['V', 'C', 'G', 'F', 'J', 'T']) 1
# deque(['W', 'V']) deque([]) 1
# deque(['W']) deque(['V']) 1
# deque(['V']) deque(['R', 'S', 'L', 'D', 'Z', 'Q', 'D', 'V', 'M', 'R', 'J']) 1
# deque([]) deque(['R', 'S', 'L', 'D', 'Z', 'Q', 'D', 'V', 'M', 'R', 'J', 'V']) 1
# deque(['J', 'R', 'F', 'D', 'P', 'C', 'N']) deque(['V', 'C', 'G', 'F', 'J', 'T']) 7
# deque([]) deque(['V', 'C', 'G', 'F', 'J', 'T', 'J', 'R', 'F', 'D', 'P', 'C', 'N']) 7
# deque(['Z', 'W', 'L', 'P', 'V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'R', 'P', 'N', 'B', 'Z', 'H', 'L', 'W', 'J', 'B']) deque(['H']) 10
# deque(['Z', 'W', 'L', 'P', 'V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C']) deque(['H', 'R', 'P', 'N', 'B', 'Z', 'H', 'L', 'W', 'J', 'B']) 10
# deque(['V', 'C', 'G', 'F', 'J', 'T', 'J', 'R', 'F', 'D', 'P', 'C', 'N']) deque(['H']) 10
# deque(['V', 'C', 'G']) deque(['H', 'F', 'J', 'T', 'J', 'R', 'F', 'D', 'P', 'C', 'N']) 10
# deque(['H', 'F', 'J', 'T', 'J', 'R', 'F', 'D', 'P', 'C', 'N']) deque([]) 2
# deque(['H', 'F', 'J', 'T', 'J', 'R', 'F', 'D', 'P']) deque(['C', 'N']) 2
# deque(['C', 'N']) deque(['H', 'R', 'P', 'N', 'B', 'Z', 'H', 'L', 'W', 'J', 'B']) 2
# deque([]) deque(['H', 'R', 'P', 'N', 'B', 'Z', 'H', 'L', 'W', 'J', 'B', 'C', 'N']) 2
# deque(['R', 'S', 'L', 'D', 'Z', 'Q', 'D', 'V', 'M', 'R', 'J', 'V']) deque(['Z', 'W', 'L', 'P', 'V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C']) 11
# deque(['R']) deque(['Z', 'W', 'L', 'P', 'V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'L', 'D', 'Z', 'Q', 'D', 'V', 'M', 'R', 'J', 'V']) 11
# deque(['H', 'R', 'P', 'N', 'B', 'Z', 'H', 'L', 'W', 'J', 'B', 'C', 'N']) deque(['V', 'C', 'G']) 7
# deque(['H', 'R', 'P', 'N', 'B', 'Z']) deque(['V', 'C', 'G', 'H', 'L', 'W', 'J', 'B', 'C', 'N']) 7
# deque(['W']) deque(['H', 'R', 'P', 'N', 'B', 'Z']) 1
# deque([]) deque(['H', 'R', 'P', 'N', 'B', 'Z', 'W']) 1
# deque(['R']) deque(['D', 'V', 'L', 'V', 'M', 'B']) 1
# deque([]) deque(['D', 'V', 'L', 'V', 'M', 'B', 'R']) 1
# deque(['V', 'C', 'G', 'H', 'L', 'W', 'J', 'B', 'C', 'N']) deque([]) 1
# deque(['V', 'C', 'G', 'H', 'L', 'W', 'J', 'B', 'C']) deque(['N']) 1
# deque(['V', 'C', 'G', 'H', 'L', 'W', 'J', 'B', 'C']) deque(['H', 'F', 'J', 'T', 'J', 'R', 'F', 'D', 'P']) 6
# deque(['V', 'C', 'G']) deque(['H', 'F', 'J', 'T', 'J', 'R', 'F', 'D', 'P', 'H', 'L', 'W', 'J', 'B', 'C']) 6
# deque(['H', 'F', 'J', 'T', 'J', 'R', 'F', 'D', 'P', 'H', 'L', 'W', 'J', 'B', 'C']) deque([]) 1
# deque(['H', 'F', 'J', 'T', 'J', 'R', 'F', 'D', 'P', 'H', 'L', 'W', 'J', 'B']) deque(['C']) 1
# deque(['N']) deque([]) 1
# deque([]) deque(['N']) 1
# deque(['H', 'R', 'P', 'N', 'B', 'Z', 'W']) deque([]) 6
# deque(['H']) deque(['R', 'P', 'N', 'B', 'Z', 'W']) 6
# deque(['Z', 'W', 'L', 'P', 'V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'L', 'D', 'Z', 'Q', 'D', 'V', 'M', 'R', 'J', 'V']) deque([]) 19
# deque(['Z', 'W', 'L', 'P']) deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'L', 'D', 'Z', 'Q', 'D', 'V', 'M', 'R', 'J', 'V']) 19
# deque(['H']) deque(['N']) 1
# deque([]) deque(['N', 'H']) 1
# deque(['V', 'C', 'G']) deque(['C']) 1
# deque(['V', 'C']) deque(['C', 'G']) 1
# deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'L', 'D', 'Z', 'Q', 'D', 'V', 'M', 'R', 'J', 'V']) deque(['R', 'P', 'N', 'B', 'Z', 'W']) 9
# deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'L']) deque(['R', 'P', 'N', 'B', 'Z', 'W', 'D', 'Z', 'Q', 'D', 'V', 'M', 'R', 'J', 'V']) 9
# deque(['Z', 'W', 'L', 'P']) deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'L']) 1
# deque(['Z', 'W', 'L']) deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'L', 'P']) 1
# deque(['N', 'H']) deque([]) 2
# deque([]) deque(['N', 'H']) 2
# deque(['N', 'H']) deque(['Z', 'W', 'L']) 1
# deque(['N']) deque(['Z', 'W', 'L', 'H']) 1
# deque(['D', 'V', 'L', 'V', 'M', 'B', 'R']) deque(['R', 'P', 'N', 'B', 'Z', 'W', 'D', 'Z', 'Q', 'D', 'V', 'M', 'R', 'J', 'V']) 7
# deque([]) deque(['R', 'P', 'N', 'B', 'Z', 'W', 'D', 'Z', 'Q', 'D', 'V', 'M', 'R', 'J', 'V', 'D', 'V', 'L', 'V', 'M', 'B', 'R']) 7
# deque(['Z', 'W', 'L', 'H']) deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'L', 'P']) 3
# deque(['Z']) deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'L', 'P', 'W', 'L', 'H']) 3
# deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'L', 'P', 'W', 'L', 'H']) deque(['R', 'P', 'N', 'B', 'Z', 'W', 'D', 'Z', 'Q', 'D', 'V', 'M', 'R', 'J', 'V', 'D', 'V', 'L', 'V', 'M', 'B', 'R']) 5
# deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S']) deque(['R', 'P', 'N', 'B', 'Z', 'W', 'D', 'Z', 'Q', 'D', 'V', 'M', 'R', 'J', 'V', 'D', 'V', 'L', 'V', 'M', 'B', 'R', 'L', 'P', 'W', 'L', 'H']) 5
# deque(['Z']) deque([]) 1
# deque([]) deque(['Z']) 1
# deque(['R', 'P', 'N', 'B', 'Z', 'W', 'D', 'Z', 'Q', 'D', 'V', 'M', 'R', 'J', 'V', 'D', 'V', 'L', 'V', 'M', 'B', 'R', 'L', 'P', 'W', 'L', 'H']) deque(['C', 'G']) 15
# deque(['R', 'P', 'N', 'B', 'Z', 'W', 'D', 'Z', 'Q', 'D', 'V', 'M']) deque(['C', 'G', 'R', 'J', 'V', 'D', 'V', 'L', 'V', 'M', 'B', 'R', 'L', 'P', 'W', 'L', 'H']) 15
# deque(['R', 'P', 'N', 'B', 'Z', 'W', 'D', 'Z', 'Q', 'D', 'V', 'M']) deque(['C', 'G', 'R', 'J', 'V', 'D', 'V', 'L', 'V', 'M', 'B', 'R', 'L', 'P', 'W', 'L', 'H']) 6
# deque(['R', 'P', 'N', 'B', 'Z', 'W']) deque(['C', 'G', 'R', 'J', 'V', 'D', 'V', 'L', 'V', 'M', 'B', 'R', 'L', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'M']) 6
# deque(['N']) deque([]) 1
# deque([]) deque(['N']) 1
# deque(['R', 'P', 'N', 'B', 'Z', 'W']) deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S']) 5
# deque(['R']) deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'P', 'N', 'B', 'Z', 'W']) 5
# deque(['R']) deque([]) 1
# deque([]) deque(['R']) 1
# deque(['H', 'F', 'J', 'T', 'J', 'R', 'F', 'D', 'P', 'H', 'L', 'W', 'J', 'B']) deque([]) 6
# deque(['H', 'F', 'J', 'T', 'J', 'R', 'F', 'D']) deque(['P', 'H', 'L', 'W', 'J', 'B']) 6
# deque(['Z']) deque(['V', 'C']) 1
# deque([]) deque(['V', 'C', 'Z']) 1
# deque(['N']) deque(['C', 'G', 'R', 'J', 'V', 'D', 'V', 'L', 'V', 'M', 'B', 'R', 'L', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'M']) 1
# deque([]) deque(['C', 'G', 'R', 'J', 'V', 'D', 'V', 'L', 'V', 'M', 'B', 'R', 'L', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'M', 'N']) 1
# deque(['P', 'H', 'L', 'W', 'J', 'B']) deque(['R']) 6
# deque([]) deque(['R', 'P', 'H', 'L', 'W', 'J', 'B']) 6
# deque(['V', 'C', 'Z']) deque([]) 3
# deque([]) deque(['V', 'C', 'Z']) 3
# deque(['V', 'C', 'Z']) deque(['R', 'P', 'H', 'L', 'W', 'J', 'B']) 1
# deque(['V', 'C']) deque(['R', 'P', 'H', 'L', 'W', 'J', 'B', 'Z']) 1
# deque(['H', 'F', 'J', 'T', 'J', 'R', 'F', 'D']) deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'P', 'N', 'B', 'Z', 'W']) 3
# deque(['H', 'F', 'J', 'T', 'J']) deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'P', 'N', 'B', 'Z', 'W', 'R', 'F', 'D']) 3
# deque(['H', 'F', 'J', 'T', 'J']) deque(['C', 'G', 'R', 'J', 'V', 'D', 'V', 'L', 'V', 'M', 'B', 'R', 'L', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'M', 'N']) 1
# deque(['H', 'F', 'J', 'T']) deque(['C', 'G', 'R', 'J', 'V', 'D', 'V', 'L', 'V', 'M', 'B', 'R', 'L', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'M', 'N', 'J']) 1
# deque(['R', 'P', 'H', 'L', 'W', 'J', 'B', 'Z']) deque(['H', 'F', 'J', 'T']) 5
# deque(['R', 'P', 'H']) deque(['H', 'F', 'J', 'T', 'L', 'W', 'J', 'B', 'Z']) 5
# deque(['V', 'C']) deque([]) 2
# deque([]) deque(['V', 'C']) 2
# deque(['V', 'C']) deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'P', 'N', 'B', 'Z', 'W', 'R', 'F', 'D']) 2
# deque([]) deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'P', 'N', 'B', 'Z', 'W', 'R', 'F', 'D', 'V', 'C']) 2
# deque(['H', 'F', 'J', 'T', 'L', 'W', 'J', 'B', 'Z']) deque(['R', 'P', 'H']) 7
# deque(['H', 'F']) deque(['R', 'P', 'H', 'J', 'T', 'L', 'W', 'J', 'B', 'Z']) 7
# deque(['H', 'F']) deque(['C', 'G', 'R', 'J', 'V', 'D', 'V', 'L', 'V', 'M', 'B', 'R', 'L', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'M', 'N', 'J']) 1
# deque(['H']) deque(['C', 'G', 'R', 'J', 'V', 'D', 'V', 'L', 'V', 'M', 'B', 'R', 'L', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'M', 'N', 'J', 'F']) 1
# deque(['H']) deque([]) 1
# deque([]) deque(['H']) 1
# deque(['C', 'G', 'R', 'J', 'V', 'D', 'V', 'L', 'V', 'M', 'B', 'R', 'L', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'M', 'N', 'J', 'F']) deque(['R', 'P', 'H', 'J', 'T', 'L', 'W', 'J', 'B', 'Z']) 20
# deque(['C', 'G', 'R', 'J', 'V', 'D']) deque(['R', 'P', 'H', 'J', 'T', 'L', 'W', 'J', 'B', 'Z', 'V', 'L', 'V', 'M', 'B', 'R', 'L', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'M', 'N', 'J', 'F']) 20
# deque(['R', 'P', 'H', 'J', 'T', 'L', 'W', 'J', 'B', 'Z', 'V', 'L', 'V', 'M', 'B', 'R', 'L', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'M', 'N', 'J', 'F']) deque(['C', 'G', 'R', 'J', 'V', 'D']) 23
# deque(['R', 'P', 'H', 'J', 'T', 'L', 'W']) deque(['C', 'G', 'R', 'J', 'V', 'D', 'J', 'B', 'Z', 'V', 'L', 'V', 'M', 'B', 'R', 'L', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'M', 'N', 'J', 'F']) 23
# deque(['R', 'P', 'H', 'J', 'T', 'L', 'W']) deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'P', 'N', 'B', 'Z', 'W', 'R', 'F', 'D', 'V', 'C']) 1
# deque(['R', 'P', 'H', 'J', 'T', 'L']) deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'P', 'N', 'B', 'Z', 'W', 'R', 'F', 'D', 'V', 'C', 'W']) 1
# deque(['C', 'G', 'R', 'J', 'V', 'D', 'J', 'B', 'Z', 'V', 'L', 'V', 'M', 'B', 'R', 'L', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'M', 'N', 'J', 'F']) deque(['H']) 4
# deque(['C', 'G', 'R', 'J', 'V', 'D', 'J', 'B', 'Z', 'V', 'L', 'V', 'M', 'B', 'R', 'L', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V']) deque(['H', 'M', 'N', 'J', 'F']) 4
# deque(['H', 'M', 'N', 'J', 'F']) deque([]) 4
# deque(['H']) deque(['M', 'N', 'J', 'F']) 4
# deque(['H']) deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'P', 'N', 'B', 'Z', 'W', 'R', 'F', 'D', 'V', 'C', 'W']) 1
# deque([]) deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'P', 'N', 'B', 'Z', 'W', 'R', 'F', 'D', 'V', 'C', 'W', 'H']) 1
# deque(['C', 'G', 'R', 'J', 'V', 'D', 'J', 'B', 'Z', 'V', 'L', 'V', 'M', 'B', 'R', 'L', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V']) deque([]) 16
# deque(['C', 'G', 'R', 'J', 'V', 'D', 'J', 'B', 'Z']) deque(['V', 'L', 'V', 'M', 'B', 'R', 'L', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V']) 16
# deque(['R', 'P', 'H', 'J', 'T', 'L']) deque([]) 4
# deque(['R', 'P']) deque(['H', 'J', 'T', 'L']) 4
# deque(['C', 'G', 'R', 'J', 'V', 'D', 'J', 'B', 'Z']) deque(['V', 'L', 'V', 'M', 'B', 'R', 'L', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V']) 9
# deque([]) deque(['V', 'L', 'V', 'M', 'B', 'R', 'L', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'C', 'G', 'R', 'J', 'V', 'D', 'J', 'B', 'Z']) 9
# deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'P', 'N', 'B', 'Z', 'W', 'R', 'F', 'D', 'V', 'C', 'W', 'H']) deque(['V', 'L', 'V', 'M', 'B', 'R', 'L', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'C', 'G', 'R', 'J', 'V', 'D', 'J', 'B', 'Z']) 11
# deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'P']) deque(['V', 'L', 'V', 'M', 'B', 'R', 'L', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'C', 'G', 'R', 'J', 'V', 'D', 'J', 'B', 'Z', 'N', 'B', 'Z', 'W', 'R', 'F', 'D', 'V', 'C', 'W', 'H']) 11
# deque(['R', 'P']) deque([]) 1
# deque(['R']) deque(['P']) 1
# deque(['R']) deque([]) 1
# deque([]) deque(['R']) 1
# deque(['M', 'N', 'J', 'F']) deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'P']) 1
# deque(['M', 'N', 'J']) deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'P', 'F']) 1
# deque(['P']) deque(['R']) 1
# deque([]) deque(['R', 'P']) 1
# deque(['H', 'J', 'T', 'L']) deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'P', 'F']) 4
# deque([]) deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'P', 'F', 'H', 'J', 'T', 'L']) 4
# deque(['M', 'N', 'J']) deque([]) 3
# deque([]) deque(['M', 'N', 'J']) 3
# deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'P', 'F', 'H', 'J', 'T', 'L']) deque([]) 2
# deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'P', 'F', 'H', 'J']) deque(['T', 'L']) 2
# deque(['R', 'P']) deque(['T', 'L']) 2
# deque([]) deque(['T', 'L', 'R', 'P']) 2
# deque(['T', 'L', 'R', 'P']) deque([]) 4
# deque([]) deque(['T', 'L', 'R', 'P']) 4
# deque(['V', 'L', 'V', 'M', 'B', 'R', 'L', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'C', 'G', 'R', 'J', 'V', 'D', 'J', 'B', 'Z', 'N', 'B', 'Z', 'W', 'R', 'F', 'D', 'V', 'C', 'W', 'H']) deque(['T', 'L', 'R', 'P']) 28
# deque(['V', 'L', 'V', 'M', 'B', 'R', 'L', 'P']) deque(['T', 'L', 'R', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'C', 'G', 'R', 'J', 'V', 'D', 'J', 'B', 'Z', 'N', 'B', 'Z', 'W', 'R', 'F', 'D', 'V', 'C', 'W', 'H']) 28
# deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C', 'S', 'P', 'F', 'H', 'J']) deque([]) 5
# deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C']) deque(['S', 'P', 'F', 'H', 'J']) 5
# deque(['V', 'L', 'V', 'M', 'B', 'R', 'L', 'P']) deque([]) 8
# deque([]) deque(['V', 'L', 'V', 'M', 'B', 'R', 'L', 'P']) 8
# deque(['V', 'Q', 'D', 'Q', 'G', 'R', 'P', 'C']) deque([]) 6
# deque(['V', 'Q']) deque(['D', 'Q', 'G', 'R', 'P', 'C']) 6
# deque(['S', 'P', 'F', 'H', 'J']) deque(['M', 'N', 'J']) 2
# deque(['S', 'P', 'F']) deque(['M', 'N', 'J', 'H', 'J']) 2
# deque(['V', 'L', 'V', 'M', 'B', 'R', 'L', 'P']) deque(['S', 'P', 'F']) 5
# deque(['V', 'L', 'V']) deque(['S', 'P', 'F', 'M', 'B', 'R', 'L', 'P']) 5
# deque(['V', 'L', 'V']) deque(['T', 'L', 'R', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'C', 'G', 'R', 'J', 'V', 'D', 'J', 'B', 'Z', 'N', 'B', 'Z', 'W', 'R', 'F', 'D', 'V', 'C', 'W', 'H']) 1
# deque(['V', 'L']) deque(['T', 'L', 'R', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'C', 'G', 'R', 'J', 'V', 'D', 'J', 'B', 'Z', 'N', 'B', 'Z', 'W', 'R', 'F', 'D', 'V', 'C', 'W', 'H', 'V']) 1
# deque(['T', 'L', 'R', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'C', 'G', 'R', 'J', 'V', 'D', 'J', 'B', 'Z', 'N', 'B', 'Z', 'W', 'R', 'F', 'D', 'V', 'C', 'W', 'H', 'V']) deque([]) 14
# deque(['T', 'L', 'R', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'C', 'G', 'R', 'J', 'V', 'D', 'J']) deque(['B', 'Z', 'N', 'B', 'Z', 'W', 'R', 'F', 'D', 'V', 'C', 'W', 'H', 'V']) 14
# deque(['T', 'L', 'R', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'C', 'G', 'R', 'J', 'V', 'D', 'J']) deque([]) 18
# deque(['T']) deque(['L', 'R', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'C', 'G', 'R', 'J', 'V', 'D', 'J']) 18
# deque(['D', 'Q', 'G', 'R', 'P', 'C']) deque(['B', 'Z', 'N', 'B', 'Z', 'W', 'R', 'F', 'D', 'V', 'C', 'W', 'H', 'V']) 5
# deque(['D']) deque(['B', 'Z', 'N', 'B', 'Z', 'W', 'R', 'F', 'D', 'V', 'C', 'W', 'H', 'V', 'Q', 'G', 'R', 'P', 'C']) 5
# deque(['S', 'P', 'F', 'M', 'B', 'R', 'L', 'P']) deque(['L', 'R', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'C', 'G', 'R', 'J', 'V', 'D', 'J']) 6
# deque(['S', 'P']) deque(['L', 'R', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'C', 'G', 'R', 'J', 'V', 'D', 'J', 'F', 'M', 'B', 'R', 'L', 'P']) 6
# deque(['V', 'Q']) deque(['D']) 1
# deque(['V']) deque(['D', 'Q']) 1
# deque(['B', 'Z', 'N', 'B', 'Z', 'W', 'R', 'F', 'D', 'V', 'C', 'W', 'H', 'V', 'Q', 'G', 'R', 'P', 'C']) deque(['S', 'P']) 19
# deque([]) deque(['S', 'P', 'B', 'Z', 'N', 'B', 'Z', 'W', 'R', 'F', 'D', 'V', 'C', 'W', 'H', 'V', 'Q', 'G', 'R', 'P', 'C']) 19
# deque(['V']) deque(['V', 'L']) 1
# deque([]) deque(['V', 'L', 'V']) 1
# deque(['T']) deque(['M', 'N', 'J', 'H', 'J']) 1
# deque([]) deque(['M', 'N', 'J', 'H', 'J', 'T']) 1
# deque(['V', 'L', 'V']) deque([]) 2
# deque(['V']) deque(['L', 'V']) 2
# deque(['S', 'P', 'B', 'Z', 'N', 'B', 'Z', 'W', 'R', 'F', 'D', 'V', 'C', 'W', 'H', 'V', 'Q', 'G', 'R', 'P', 'C']) deque(['M', 'N', 'J', 'H', 'J', 'T']) 14
# deque(['S', 'P', 'B', 'Z', 'N', 'B', 'Z']) deque(['M', 'N', 'J', 'H', 'J', 'T', 'W', 'R', 'F', 'D', 'V', 'C', 'W', 'H', 'V', 'Q', 'G', 'R', 'P', 'C']) 14
# deque(['V']) deque(['M', 'N', 'J', 'H', 'J', 'T', 'W', 'R', 'F', 'D', 'V', 'C', 'W', 'H', 'V', 'Q', 'G', 'R', 'P', 'C']) 1
# deque([]) deque(['M', 'N', 'J', 'H', 'J', 'T', 'W', 'R', 'F', 'D', 'V', 'C', 'W', 'H', 'V', 'Q', 'G', 'R', 'P', 'C', 'V']) 1
# deque(['L', 'R', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'C', 'G', 'R', 'J', 'V', 'D', 'J', 'F', 'M', 'B', 'R', 'L', 'P']) deque(['D', 'Q']) 12
# deque(['L', 'R', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'C']) deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'F', 'M', 'B', 'R', 'L', 'P']) 12
# deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'F', 'M', 'B', 'R', 'L', 'P']) deque([]) 6
# deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J']) deque(['F', 'M', 'B', 'R', 'L', 'P']) 6
# deque(['F', 'M', 'B', 'R', 'L', 'P']) deque([]) 4
# deque(['F', 'M']) deque(['B', 'R', 'L', 'P']) 4
# deque(['M', 'N', 'J', 'H', 'J', 'T', 'W', 'R', 'F', 'D', 'V', 'C', 'W', 'H', 'V', 'Q', 'G', 'R', 'P', 'C', 'V']) deque(['B', 'R', 'L', 'P']) 21
# deque([]) deque(['B', 'R', 'L', 'P', 'M', 'N', 'J', 'H', 'J', 'T', 'W', 'R', 'F', 'D', 'V', 'C', 'W', 'H', 'V', 'Q', 'G', 'R', 'P', 'C', 'V']) 21
# deque(['L', 'R', 'P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'C']) deque([]) 10
# deque(['L', 'R']) deque(['P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'C']) 10
# deque(['P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'C']) deque(['L', 'V']) 2
# deque(['P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D']) deque(['L', 'V', 'V', 'C']) 2
# deque(['B', 'R', 'L', 'P', 'M', 'N', 'J', 'H', 'J', 'T', 'W', 'R', 'F', 'D', 'V', 'C', 'W', 'H', 'V', 'Q', 'G', 'R', 'P', 'C', 'V']) deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J']) 7
# deque(['B', 'R', 'L', 'P', 'M', 'N', 'J', 'H', 'J', 'T', 'W', 'R', 'F', 'D', 'V', 'C', 'W', 'H']) deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V']) 7
# deque(['L', 'R']) deque([]) 2
# deque([]) deque(['L', 'R']) 2
# deque(['L', 'V', 'V', 'C']) deque(['P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D']) 2
# deque(['L', 'V']) deque(['P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'C']) 2
# deque(['S', 'P', 'B', 'Z', 'N', 'B', 'Z']) deque(['L', 'V']) 5
# deque(['S', 'P']) deque(['L', 'V', 'B', 'Z', 'N', 'B', 'Z']) 5
# deque(['L', 'R']) deque(['B', 'R', 'L', 'P', 'M', 'N', 'J', 'H', 'J', 'T', 'W', 'R', 'F', 'D', 'V', 'C', 'W', 'H']) 2
# deque([]) deque(['B', 'R', 'L', 'P', 'M', 'N', 'J', 'H', 'J', 'T', 'W', 'R', 'F', 'D', 'V', 'C', 'W', 'H', 'L', 'R']) 2
# deque(['P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'D', 'V', 'C']) deque(['S', 'P']) 3
# deque(['P', 'W', 'L', 'H', 'D', 'Z', 'Q']) deque(['S', 'P', 'D', 'V', 'C']) 3
# deque(['F', 'M']) deque(['S', 'P', 'D', 'V', 'C']) 2
# deque([]) deque(['S', 'P', 'D', 'V', 'C', 'F', 'M']) 2
# deque(['L', 'V', 'B', 'Z', 'N', 'B', 'Z']) deque(['S', 'P', 'D', 'V', 'C', 'F', 'M']) 2
# deque(['L', 'V', 'B', 'Z', 'N']) deque(['S', 'P', 'D', 'V', 'C', 'F', 'M', 'B', 'Z']) 2
# deque(['L', 'V', 'B', 'Z', 'N']) deque(['P', 'W', 'L', 'H', 'D', 'Z', 'Q']) 2
# deque(['L', 'V', 'B']) deque(['P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'Z', 'N']) 2
# deque(['B', 'R', 'L', 'P', 'M', 'N', 'J', 'H', 'J', 'T', 'W', 'R', 'F', 'D', 'V', 'C', 'W', 'H', 'L', 'R']) deque([]) 7
# deque(['B', 'R', 'L', 'P', 'M', 'N', 'J', 'H', 'J', 'T', 'W', 'R', 'F']) deque(['D', 'V', 'C', 'W', 'H', 'L', 'R']) 7
# deque(['D', 'V', 'C', 'W', 'H', 'L', 'R']) deque(['B', 'R', 'L', 'P', 'M', 'N', 'J', 'H', 'J', 'T', 'W', 'R', 'F']) 3
# deque(['D', 'V', 'C', 'W']) deque(['B', 'R', 'L', 'P', 'M', 'N', 'J', 'H', 'J', 'T', 'W', 'R', 'F', 'H', 'L', 'R']) 3
# deque(['L', 'V', 'B']) deque([]) 3
# deque([]) deque(['L', 'V', 'B']) 3
# deque(['D', 'V', 'C', 'W']) deque(['L', 'V', 'B']) 2
# deque(['D', 'V']) deque(['L', 'V', 'B', 'C', 'W']) 2
# deque(['B', 'R', 'L', 'P', 'M', 'N', 'J', 'H', 'J', 'T', 'W', 'R', 'F', 'H', 'L', 'R']) deque(['P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'Z', 'N']) 7
# deque(['B', 'R', 'L', 'P', 'M', 'N', 'J', 'H', 'J']) deque(['P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'Z', 'N', 'T', 'W', 'R', 'F', 'H', 'L', 'R']) 7
# deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V']) deque([]) 15
# deque([]) deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V']) 15
# deque(['D', 'V']) deque(['B', 'R', 'L', 'P', 'M', 'N', 'J', 'H', 'J']) 1
# deque(['D']) deque(['B', 'R', 'L', 'P', 'M', 'N', 'J', 'H', 'J', 'V']) 1
# deque(['L', 'V', 'B', 'C', 'W']) deque(['D']) 1
# deque(['L', 'V', 'B', 'C']) deque(['D', 'W']) 1
# deque(['P', 'W', 'L', 'H', 'D', 'Z', 'Q', 'Z', 'N', 'T', 'W', 'R', 'F', 'H', 'L', 'R']) deque(['D', 'W']) 14
# deque(['P', 'W']) deque(['D', 'W', 'L', 'H', 'D', 'Z', 'Q', 'Z', 'N', 'T', 'W', 'R', 'F', 'H', 'L', 'R']) 14
# deque(['B', 'R', 'L', 'P', 'M', 'N', 'J', 'H', 'J', 'V']) deque(['D', 'W', 'L', 'H', 'D', 'Z', 'Q', 'Z', 'N', 'T', 'W', 'R', 'F', 'H', 'L', 'R']) 9
# deque(['B']) deque(['D', 'W', 'L', 'H', 'D', 'Z', 'Q', 'Z', 'N', 'T', 'W', 'R', 'F', 'H', 'L', 'R', 'R', 'L', 'P', 'M', 'N', 'J', 'H', 'J', 'V']) 9
# deque(['S', 'P', 'D', 'V', 'C', 'F', 'M', 'B', 'Z']) deque(['D', 'W', 'L', 'H', 'D', 'Z', 'Q', 'Z', 'N', 'T', 'W', 'R', 'F', 'H', 'L', 'R', 'R', 'L', 'P', 'M', 'N', 'J', 'H', 'J', 'V']) 5
# deque(['S', 'P', 'D', 'V']) deque(['D', 'W', 'L', 'H', 'D', 'Z', 'Q', 'Z', 'N', 'T', 'W', 'R', 'F', 'H', 'L', 'R', 'R', 'L', 'P', 'M', 'N', 'J', 'H', 'J', 'V', 'C', 'F', 'M', 'B', 'Z']) 5
# deque(['P', 'W']) deque(['L', 'V', 'B', 'C']) 1
# deque(['P']) deque(['L', 'V', 'B', 'C', 'W']) 1
# deque(['B']) deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V']) 1
# deque([]) deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B']) 1
# deque(['D', 'W', 'L', 'H', 'D', 'Z', 'Q', 'Z', 'N', 'T', 'W', 'R', 'F', 'H', 'L', 'R', 'R', 'L', 'P', 'M', 'N', 'J', 'H', 'J', 'V', 'C', 'F', 'M', 'B', 'Z']) deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B']) 20
# deque(['D', 'W', 'L', 'H', 'D', 'Z', 'Q', 'Z', 'N', 'T']) deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'H', 'L', 'R', 'R', 'L', 'P', 'M', 'N', 'J', 'H', 'J', 'V', 'C', 'F', 'M', 'B', 'Z']) 20
# deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'H', 'L', 'R', 'R', 'L', 'P', 'M', 'N', 'J', 'H', 'J', 'V', 'C', 'F', 'M', 'B', 'Z']) deque(['L', 'V', 'B', 'C', 'W']) 17
# deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F']) deque(['L', 'V', 'B', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'P', 'M', 'N', 'J', 'H', 'J', 'V', 'C', 'F', 'M', 'B', 'Z']) 17
# deque(['P']) deque(['S', 'P', 'D', 'V']) 1
# deque([]) deque(['S', 'P', 'D', 'V', 'P']) 1
# deque(['S', 'P', 'D', 'V', 'P']) deque([]) 5
# deque([]) deque(['S', 'P', 'D', 'V', 'P']) 5
# deque(['L', 'V', 'B', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'P', 'M', 'N', 'J', 'H', 'J', 'V', 'C', 'F', 'M', 'B', 'Z']) deque(['D', 'W', 'L', 'H', 'D', 'Z', 'Q', 'Z', 'N', 'T']) 6
# deque(['L', 'V', 'B', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'P', 'M', 'N', 'J', 'H', 'J']) deque(['D', 'W', 'L', 'H', 'D', 'Z', 'Q', 'Z', 'N', 'T', 'V', 'C', 'F', 'M', 'B', 'Z']) 6
# deque(['S', 'P', 'D', 'V', 'P']) deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F']) 3
# deque(['S', 'P']) deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P']) 3
# deque(['D', 'W', 'L', 'H', 'D', 'Z', 'Q', 'Z', 'N', 'T', 'V', 'C', 'F', 'M', 'B', 'Z']) deque([]) 10
# deque(['D', 'W', 'L', 'H', 'D', 'Z']) deque(['Q', 'Z', 'N', 'T', 'V', 'C', 'F', 'M', 'B', 'Z']) 10
# deque(['L', 'V', 'B', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'P', 'M', 'N', 'J', 'H', 'J']) deque([]) 3
# deque(['L', 'V', 'B', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'P', 'M', 'N']) deque(['J', 'H', 'J']) 3
# deque(['L', 'V', 'B', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'P', 'M', 'N']) deque(['J', 'H', 'J']) 12
# deque(['L']) deque(['J', 'H', 'J', 'V', 'B', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'P', 'M', 'N']) 12
# deque(['L']) deque(['D', 'W', 'L', 'H', 'D', 'Z']) 1
# deque([]) deque(['D', 'W', 'L', 'H', 'D', 'Z', 'L']) 1
# deque(['J', 'H', 'J', 'V', 'B', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'P', 'M', 'N']) deque([]) 15
# deque([]) deque(['J', 'H', 'J', 'V', 'B', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'P', 'M', 'N']) 15
# deque(['J', 'H', 'J', 'V', 'B', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'P', 'M', 'N']) deque(['S', 'P']) 13
# deque(['J', 'H']) deque(['S', 'P', 'J', 'V', 'B', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'P', 'M', 'N']) 13
# deque(['J', 'H']) deque(['D', 'W', 'L', 'H', 'D', 'Z', 'L']) 1
# deque(['J']) deque(['D', 'W', 'L', 'H', 'D', 'Z', 'L', 'H']) 1
# deque(['S', 'P', 'J', 'V', 'B', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'P', 'M', 'N']) deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P']) 10
# deque(['S', 'P', 'J', 'V', 'B']) deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'P', 'M', 'N']) 10
# deque(['S', 'P', 'J', 'V', 'B']) deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'P', 'M', 'N']) 3
# deque(['S', 'P']) deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'P', 'M', 'N', 'J', 'V', 'B']) 3
# deque(['J']) deque(['S', 'P']) 1
# deque([]) deque(['S', 'P', 'J']) 1
# deque(['S', 'P', 'J']) deque([]) 2
# deque(['S']) deque(['P', 'J']) 2
# deque(['S']) deque([]) 1
# deque([]) deque(['S']) 1
# deque(['P', 'J']) deque(['S']) 2
# deque([]) deque(['S', 'P', 'J']) 2
# deque(['S', 'P', 'J']) deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'P', 'M', 'N', 'J', 'V', 'B']) 3
# deque([]) deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'P', 'M', 'N', 'J', 'V', 'B', 'S', 'P', 'J']) 3
# deque(['Q', 'Z', 'N', 'T', 'V', 'C', 'F', 'M', 'B', 'Z']) deque([]) 8
# deque(['Q', 'Z']) deque(['N', 'T', 'V', 'C', 'F', 'M', 'B', 'Z']) 8
# deque(['N', 'T', 'V', 'C', 'F', 'M', 'B', 'Z']) deque([]) 8
# deque([]) deque(['N', 'T', 'V', 'C', 'F', 'M', 'B', 'Z']) 8
# deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'P', 'M', 'N', 'J', 'V', 'B', 'S', 'P', 'J']) deque(['D', 'W', 'L', 'H', 'D', 'Z', 'L', 'H']) 7
# deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'P', 'M']) deque(['D', 'W', 'L', 'H', 'D', 'Z', 'L', 'H', 'N', 'J', 'V', 'B', 'S', 'P', 'J']) 7
# deque(['N', 'T', 'V', 'C', 'F', 'M', 'B', 'Z']) deque([]) 5
# deque(['N', 'T', 'V']) deque(['C', 'F', 'M', 'B', 'Z']) 5
# deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'P', 'M']) deque([]) 2
# deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'L', 'R', 'R', 'L']) deque(['P', 'M']) 2
# deque(['D', 'W', 'L', 'H', 'D', 'Z', 'L', 'H', 'N', 'J', 'V', 'B', 'S', 'P', 'J']) deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'L', 'R', 'R', 'L']) 13
# deque(['D', 'W']) deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'L', 'H', 'D', 'Z', 'L', 'H', 'N', 'J', 'V', 'B', 'S', 'P', 'J']) 13
# deque(['P', 'M']) deque(['N', 'T', 'V']) 2
# deque([]) deque(['N', 'T', 'V', 'P', 'M']) 2
# deque(['Q', 'Z']) deque(['C', 'F', 'M', 'B', 'Z']) 2
# deque([]) deque(['C', 'F', 'M', 'B', 'Z', 'Q', 'Z']) 2
# deque(['N', 'T', 'V', 'P', 'M']) deque(['D', 'W']) 3
# deque(['N', 'T']) deque(['D', 'W', 'V', 'P', 'M']) 3
# deque(['D', 'W', 'V', 'P', 'M']) deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'L', 'H', 'D', 'Z', 'L', 'H', 'N', 'J', 'V', 'B', 'S', 'P', 'J']) 2
# deque(['D', 'W', 'V']) deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'L', 'H', 'D', 'Z', 'L', 'H', 'N', 'J', 'V', 'B', 'S', 'P', 'J', 'P', 'M']) 2
# deque(['N', 'T']) deque([]) 2
# deque([]) deque(['N', 'T']) 2
# deque(['C', 'F', 'M', 'B', 'Z', 'Q', 'Z']) deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'L', 'H', 'D', 'Z', 'L', 'H', 'N', 'J', 'V', 'B', 'S', 'P', 'J', 'P', 'M']) 6
# deque(['C']) deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'L', 'H', 'D', 'Z', 'L', 'H', 'N', 'J', 'V', 'B', 'S', 'P', 'J', 'P', 'M', 'F', 'M', 'B', 'Z', 'Q', 'Z']) 6
# deque(['D', 'W', 'V']) deque([]) 3
# deque([]) deque(['D', 'W', 'V']) 3
# deque(['C']) deque([]) 1
# deque([]) deque(['C']) 1
# deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'L', 'R', 'R', 'L', 'L', 'H', 'D', 'Z', 'L', 'H', 'N', 'J', 'V', 'B', 'S', 'P', 'J', 'P', 'M', 'F', 'M', 'B', 'Z', 'Q', 'Z']) deque([]) 24
# deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'L']) deque(['R', 'R', 'L', 'L', 'H', 'D', 'Z', 'L', 'H', 'N', 'J', 'V', 'B', 'S', 'P', 'J', 'P', 'M', 'F', 'M', 'B', 'Z', 'Q', 'Z']) 24
# deque(['D', 'W', 'V']) deque(['C']) 2
# deque(['D']) deque(['C', 'W', 'V']) 2
# deque(['R', 'R', 'L', 'L', 'H', 'D', 'Z', 'L', 'H', 'N', 'J', 'V', 'B', 'S', 'P', 'J', 'P', 'M', 'F', 'M', 'B', 'Z', 'Q', 'Z']) deque(['N', 'T']) 15
# deque(['R', 'R', 'L', 'L', 'H', 'D', 'Z', 'L', 'H']) deque(['N', 'T', 'N', 'J', 'V', 'B', 'S', 'P', 'J', 'P', 'M', 'F', 'M', 'B', 'Z', 'Q', 'Z']) 15
# deque(['C', 'W', 'V']) deque(['D']) 1
# deque(['C', 'W']) deque(['D', 'V']) 1
# deque(['R', 'R', 'L', 'L', 'H', 'D', 'Z', 'L', 'H']) deque(['N', 'T', 'N', 'J', 'V', 'B', 'S', 'P', 'J', 'P', 'M', 'F', 'M', 'B', 'Z', 'Q', 'Z']) 9
# deque([]) deque(['N', 'T', 'N', 'J', 'V', 'B', 'S', 'P', 'J', 'P', 'M', 'F', 'M', 'B', 'Z', 'Q', 'Z', 'R', 'R', 'L', 'L', 'H', 'D', 'Z', 'L', 'H']) 9
# deque(['D', 'V']) deque(['C', 'W']) 2
# deque([]) deque(['C', 'W', 'D', 'V']) 2
# deque(['D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'L']) deque(['N', 'T', 'N', 'J', 'V', 'B', 'S', 'P', 'J', 'P', 'M', 'F', 'M', 'B', 'Z', 'Q', 'Z', 'R', 'R', 'L', 'L', 'H', 'D', 'Z', 'L', 'H']) 26
# deque([]) deque(['N', 'T', 'N', 'J', 'V', 'B', 'S', 'P', 'J', 'P', 'M', 'F', 'M', 'B', 'Z', 'Q', 'Z', 'R', 'R', 'L', 'L', 'H', 'D', 'Z', 'L', 'H', 'D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'L']) 26
# deque(['C', 'W', 'D', 'V']) deque([]) 1
# deque(['C', 'W', 'D']) deque(['V']) 1
# deque(['C', 'W', 'D']) deque(['V']) 1
# deque(['C', 'W']) deque(['V', 'D']) 1
# deque(['N', 'T', 'N', 'J', 'V', 'B', 'S', 'P', 'J', 'P', 'M', 'F', 'M', 'B', 'Z', 'Q', 'Z', 'R', 'R', 'L', 'L', 'H', 'D', 'Z', 'L', 'H', 'D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'L']) deque([]) 50
# deque(['N', 'T']) deque(['N', 'J', 'V', 'B', 'S', 'P', 'J', 'P', 'M', 'F', 'M', 'B', 'Z', 'Q', 'Z', 'R', 'R', 'L', 'L', 'H', 'D', 'Z', 'L', 'H', 'D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'L']) 50
# deque(['V', 'D']) deque([]) 1
# deque(['V']) deque(['D']) 1
# deque(['N', 'T']) deque([]) 1
# deque(['N']) deque(['T']) 1
# deque(['N']) deque(['D']) 1
# deque([]) deque(['D', 'N']) 1
# deque(['N', 'J', 'V', 'B', 'S', 'P', 'J', 'P', 'M', 'F', 'M', 'B', 'Z', 'Q', 'Z', 'R', 'R', 'L', 'L', 'H', 'D', 'Z', 'L', 'H', 'D', 'Q', 'G', 'R', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'L']) deque(['C', 'W']) 22
# deque(['N', 'J', 'V', 'B', 'S', 'P', 'J', 'P', 'M', 'F', 'M', 'B', 'Z', 'Q', 'Z', 'R', 'R', 'L', 'L', 'H', 'D', 'Z', 'L', 'H', 'D', 'Q', 'G', 'R']) deque(['C', 'W', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'L']) 22
# deque(['T']) deque([]) 1
# deque([]) deque(['T']) 1
# deque(['C', 'W', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'L']) deque(['V']) 1
# deque(['C', 'W', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H']) deque(['V', 'L']) 1
# deque(['T']) deque([]) 1
# deque([]) deque(['T']) 1
# deque(['V', 'L']) deque(['N', 'J', 'V', 'B', 'S', 'P', 'J', 'P', 'M', 'F', 'M', 'B', 'Z', 'Q', 'Z', 'R', 'R', 'L', 'L', 'H', 'D', 'Z', 'L', 'H', 'D', 'Q', 'G', 'R']) 1
# deque(['V']) deque(['N', 'J', 'V', 'B', 'S', 'P', 'J', 'P', 'M', 'F', 'M', 'B', 'Z', 'Q', 'Z', 'R', 'R', 'L', 'L', 'H', 'D', 'Z', 'L', 'H', 'D', 'Q', 'G', 'R', 'L']) 1
# deque(['N', 'J', 'V', 'B', 'S', 'P', 'J', 'P', 'M', 'F', 'M', 'B', 'Z', 'Q', 'Z', 'R', 'R', 'L', 'L', 'H', 'D', 'Z', 'L', 'H', 'D', 'Q', 'G', 'R', 'L']) deque([]) 28
# deque(['N']) deque(['J', 'V', 'B', 'S', 'P', 'J', 'P', 'M', 'F', 'M', 'B', 'Z', 'Q', 'Z', 'R', 'R', 'L', 'L', 'H', 'D', 'Z', 'L', 'H', 'D', 'Q', 'G', 'R', 'L']) 28
# deque(['D', 'N']) deque(['T']) 2
# deque([]) deque(['T', 'D', 'N']) 2
# deque(['C', 'W', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H']) deque(['V']) 21
# deque(['C', 'W']) deque(['V', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H']) 21
# deque(['N']) deque(['V', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H']) 1
# deque([]) deque(['V', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'N']) 1
# deque(['C', 'W']) deque(['V', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'N']) 1
# deque(['C']) deque(['V', 'J', 'V', 'D', 'J', 'V', 'Q', 'G', 'R', 'P', 'C', 'V', 'B', 'W', 'R', 'F', 'D', 'V', 'P', 'C', 'W', 'H', 'N', 'W']) 1
# deque(['C']) deque([]) 1
# deque([]) deque(['C']) 1
# ...
# deque(['C', 'W', 'S', 'R', 'F', 'F', 'J', 'L', 'Z']) deque([]) 1
# deque(['C', 'W', 'S', 'R', 'F', 'F', 'J', 'L']) deque(['Z']) 1
# deque(['H', 'Q', 'J', 'V', 'R']) deque(['C', 'V', 'L', 'D', 'G', 'D']) 1
# deque(['H', 'Q', 'J', 'V']) deque(['C', 'V', 'L', 'D', 'G', 'D', 'R']) 1
# deque(['H', 'Q', 'J', 'V']) deque(['Z', 'Z', 'R', 'Q', 'H', 'R']) 4
# deque([]) deque(['Z', 'Z', 'R', 'Q', 'H', 'R', 'H', 'Q', 'J', 'V']) 4
# deque(['L']) deque(['V', 'R', 'Q', 'B', 'V', 'L', 'B', 'N', 'P', 'B', 'J', 'N', 'D', 'D', 'J', 'W', 'M', 'M', 'V', 'V', 'P', 'C', 'W', 'H', 'P', 'T', 'D', 'P']) 1
# deque([]) deque(['V', 'R', 'Q', 'B', 'V', 'L', 'B', 'N', 'P', 'B', 'J', 'N', 'D', 'D', 'J', 'W', 'M', 'M', 'V', 'V', 'P', 'C', 'W', 'H', 'P', 'T', 'D', 'P', 'L']) 1
# deque(['Z', 'Z', 'R', 'Q', 'H', 'R', 'H', 'Q', 'J', 'V']) deque(['V', 'R', 'Q', 'B', 'V', 'L', 'B', 'N', 'P', 'B', 'J', 'N', 'D', 'D', 'J', 'W', 'M', 'M', 'V', 'V', 'P', 'C', 'W', 'H', 'P', 'T', 'D', 'P', 'L']) 1
# deque(['Z', 'Z', 'R', 'Q', 'H', 'R', 'H', 'Q', 'J']) deque(['V', 'R', 'Q', 'B', 'V', 'L', 'B', 'N', 'P', 'B', 'J', 'N', 'D', 'D', 'J', 'W', 'M', 'M', 'V', 'V', 'P', 'C', 'W', 'H', 'P', 'T', 'D', 'P', 'L', 'V']) 1
# deque(['V', 'R', 'Q', 'B', 'V', 'L', 'B', 'N', 'P', 'B', 'J', 'N', 'D', 'D', 'J', 'W', 'M', 'M', 'V', 'V', 'P', 'C', 'W', 'H', 'P', 'T', 'D', 'P', 'L', 'V']) deque(['Z']) 1
# deque(['V', 'R', 'Q', 'B', 'V', 'L', 'B', 'N', 'P', 'B', 'J', 'N', 'D', 'D', 'J', 'W', 'M', 'M', 'V', 'V', 'P', 'C', 'W', 'H', 'P', 'T', 'D', 'P', 'L']) deque(['Z', 'V']) 1
# deque(['Z', 'Z', 'R', 'Q', 'H', 'R', 'H', 'Q', 'J']) deque([]) 5
# deque(['Z', 'Z', 'R', 'Q']) deque(['H', 'R', 'H', 'Q', 'J']) 5
# deque(['H', 'R', 'H', 'Q', 'J']) deque([]) 1
# deque(['H', 'R', 'H', 'Q']) deque(['J']) 1
# deque(['G']) deque(['H', 'R', 'H', 'Q']) 1
# deque([]) deque(['H', 'R', 'H', 'Q', 'G']) 1
# deque(['C', 'V', 'L', 'D', 'G', 'D', 'R']) deque([]) 3
# deque(['C', 'V', 'L', 'D']) deque(['G', 'D', 'R']) 3
# deque(['J']) deque(['C', 'V', 'L', 'D']) 1
# deque([]) deque(['C', 'V', 'L', 'D', 'J']) 1
# deque(['Z', 'Z', 'R', 'Q']) deque(['V', 'R', 'Q', 'B', 'V', 'L', 'B', 'N', 'P', 'B', 'J', 'N', 'D', 'D', 'J', 'W', 'M', 'M', 'V', 'V', 'P', 'C', 'W', 'H', 'P', 'T', 'D', 'P', 'L']) 4
# deque([]) deque(['V', 'R', 'Q', 'B', 'V', 'L', 'B', 'N', 'P', 'B', 'J', 'N', 'D', 'D', 'J', 'W', 'M', 'M', 'V', 'V', 'P', 'C', 'W', 'H', 'P', 'T', 'D', 'P', 'L', 'Z', 'Z', 'R', 'Q']) 4
# deque(['Z', 'V']) deque(['V', 'R', 'Q', 'B', 'V', 'L', 'B', 'N', 'P', 'B', 'J', 'N', 'D', 'D', 'J', 'W', 'M', 'M', 'V', 'V', 'P', 'C', 'W', 'H', 'P', 'T', 'D', 'P', 'L', 'Z', 'Z', 'R', 'Q']) 1
# deque(['Z']) deque(['V', 'R', 'Q', 'B', 'V', 'L', 'B', 'N', 'P', 'B', 'J', 'N', 'D', 'D', 'J', 'W', 'M', 'M', 'V', 'V', 'P', 'C', 'W', 'H', 'P', 'T', 'D', 'P', 'L', 'Z', 'Z', 'R', 'Q', 'V']) 1
# deque(['G', 'D', 'R']) deque([]) 2
# deque(['G']) deque(['D', 'R']) 2
# deque(['Z']) deque(['C', 'W', 'S', 'R', 'F', 'F', 'J', 'L']) 1
# deque([]) deque(['C', 'W', 'S', 'R', 'F', 'F', 'J', 'L', 'Z']) 1
# deque(['H', 'R', 'H', 'Q', 'G']) deque([]) 4
# deque(['H']) deque(['R', 'H', 'Q', 'G']) 4
# deque(['G']) deque(['D', 'R']) 1
# deque([]) deque(['D', 'R', 'G']) 1
# deque(['H']) deque(['V', 'R', 'Q', 'B', 'V', 'L', 'B', 'N', 'P', 'B', 'J', 'N', 'D', 'D', 'J', 'W', 'M', 'M', 'V', 'V', 'P', 'C', 'W', 'H', 'P', 'T', 'D', 'P', 'L', 'Z', 'Z', 'R', 'Q', 'V']) 1
# deque([]) deque(['V', 'R', 'Q', 'B', 'V', 'L', 'B', 'N', 'P', 'B', 'J', 'N', 'D', 'D', 'J', 'W', 'M', 'M', 'V', 'V', 'P', 'C', 'W', 'H', 'P', 'T', 'D', 'P', 'L', 'Z', 'Z', 'R', 'Q', 'V', 'H']) 1
# deque(['V', 'R', 'Q', 'B', 'V', 'L', 'B', 'N', 'P', 'B', 'J', 'N', 'D', 'D', 'J', 'W', 'M', 'M', 'V', 'V', 'P', 'C', 'W', 'H', 'P', 'T', 'D', 'P', 'L', 'Z', 'Z', 'R', 'Q', 'V', 'H']) deque(['R', 'H', 'Q', 'G']) 22
# deque(['V', 'R', 'Q', 'B', 'V', 'L', 'B', 'N', 'P', 'B', 'J', 'N', 'D']) deque(['R', 'H', 'Q', 'G', 'D', 'J', 'W', 'M', 'M', 'V', 'V', 'P', 'C', 'W', 'H', 'P', 'T', 'D', 'P', 'L', 'Z', 'Z', 'R', 'Q', 'V', 'H']) 22
# deque(['R', 'H', 'Q', 'G', 'D', 'J', 'W', 'M', 'M', 'V', 'V', 'P', 'C', 'W', 'H', 'P', 'T', 'D', 'P', 'L', 'Z', 'Z', 'R', 'Q', 'V', 'H']) deque(['C', 'V', 'L', 'D', 'J']) 11
# deque(['R', 'H', 'Q', 'G', 'D', 'J', 'W', 'M', 'M', 'V', 'V', 'P', 'C', 'W', 'H']) deque(['C', 'V', 'L', 'D', 'J', 'P', 'T', 'D', 'P', 'L', 'Z', 'Z', 'R', 'Q', 'V', 'H']) 11
# deque(['R', 'H', 'Q', 'G', 'D', 'J', 'W', 'M', 'M', 'V', 'V', 'P', 'C', 'W', 'H']) deque(['V', 'R', 'Q', 'B', 'V', 'L', 'B', 'N', 'P', 'B', 'J', 'N', 'D']) 2
# deque(['R', 'H', 'Q', 'G', 'D', 'J', 'W', 'M', 'M', 'V', 'V', 'P', 'C']) deque(['V', 'R', 'Q', 'B', 'V', 'L', 'B', 'N', 'P', 'B', 'J', 'N', 'D', 'W', 'H']) 2
# deque(['R', 'H', 'Q', 'G', 'D', 'J', 'W', 'M', 'M', 'V', 'V', 'P', 'C']) deque(['C', 'W', 'S', 'R', 'F', 'F', 'J', 'L', 'Z']) 11
# deque(['R', 'H']) deque(['C', 'W', 'S', 'R', 'F', 'F', 'J', 'L', 'Z', 'Q', 'G', 'D', 'J', 'W', 'M', 'M', 'V', 'V', 'P', 'C']) 11
# deque(['C', 'W', 'S', 'R', 'F', 'F', 'J', 'L', 'Z', 'Q', 'G', 'D', 'J', 'W', 'M', 'M', 'V', 'V', 'P', 'C']) deque([]) 8
# deque(['C', 'W', 'S', 'R', 'F', 'F', 'J', 'L', 'Z', 'Q', 'G', 'D']) deque(['J', 'W', 'M', 'M', 'V', 'V', 'P', 'C']) 8
# deque(['D', 'R', 'G']) deque(['J', 'W', 'M', 'M', 'V', 'V', 'P', 'C']) 1
# deque(['D', 'R']) deque(['J', 'W', 'M', 'M', 'V', 'V', 'P', 'C', 'G']) 1
# deque(['C', 'V', 'L', 'D', 'J', 'P', 'T', 'D', 'P', 'L', 'Z', 'Z', 'R', 'Q', 'V', 'H']) deque([]) 7
# deque(['C', 'V', 'L', 'D', 'J', 'P', 'T', 'D', 'P']) deque(['L', 'Z', 'Z', 'R', 'Q', 'V', 'H']) 7
# deque(['J', 'W', 'M', 'M', 'V', 'V', 'P', 'C', 'G']) deque(['C', 'W', 'S', 'R', 'F', 'F', 'J', 'L', 'Z', 'Q', 'G', 'D']) 6
# deque(['J', 'W', 'M']) deque(['C', 'W', 'S', 'R', 'F', 'F', 'J', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'C', 'G']) 6
# deque(['V', 'R', 'Q', 'B', 'V', 'L', 'B', 'N', 'P', 'B', 'J', 'N', 'D', 'W', 'H']) deque(['C', 'V', 'L', 'D', 'J', 'P', 'T', 'D', 'P']) 2
# deque(['V', 'R', 'Q', 'B', 'V', 'L', 'B', 'N', 'P', 'B', 'J', 'N', 'D']) deque(['C', 'V', 'L', 'D', 'J', 'P', 'T', 'D', 'P', 'W', 'H']) 2
# deque(['J', 'W', 'M']) deque(['R', 'H']) 2
# deque(['J']) deque(['R', 'H', 'W', 'M']) 2
# deque(['C', 'W', 'S', 'R', 'F', 'F', 'J', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'C', 'G']) deque([]) 14
# deque(['C', 'W', 'S', 'R']) deque(['F', 'F', 'J', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'C', 'G']) 14
# deque(['F', 'F', 'J', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'C', 'G']) deque(['R', 'H', 'W', 'M']) 2
# deque(['F', 'F', 'J', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P']) deque(['R', 'H', 'W', 'M', 'C', 'G']) 2
# deque(['C', 'W', 'S', 'R']) deque(['J']) 3
# deque(['C']) deque(['J', 'W', 'S', 'R']) 3
# deque(['R', 'H', 'W', 'M', 'C', 'G']) deque(['F', 'F', 'J', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P']) 6
# deque([]) deque(['F', 'F', 'J', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'R', 'H', 'W', 'M', 'C', 'G']) 6
# deque(['C', 'V', 'L', 'D', 'J', 'P', 'T', 'D', 'P', 'W', 'H']) deque(['C']) 8
# deque(['C', 'V', 'L']) deque(['C', 'D', 'J', 'P', 'T', 'D', 'P', 'W', 'H']) 8
# deque(['V', 'R', 'Q', 'B', 'V', 'L', 'B', 'N', 'P', 'B', 'J', 'N', 'D']) deque(['C', 'D', 'J', 'P', 'T', 'D', 'P', 'W', 'H']) 7
# deque(['V', 'R', 'Q', 'B', 'V', 'L']) deque(['C', 'D', 'J', 'P', 'T', 'D', 'P', 'W', 'H', 'B', 'N', 'P', 'B', 'J', 'N', 'D']) 7
# deque(['C', 'D', 'J', 'P', 'T', 'D', 'P', 'W', 'H', 'B', 'N', 'P', 'B', 'J', 'N', 'D']) deque(['D', 'R']) 7
# deque(['C', 'D', 'J', 'P', 'T', 'D', 'P', 'W', 'H']) deque(['D', 'R', 'B', 'N', 'P', 'B', 'J', 'N', 'D']) 7
# deque(['C', 'V', 'L']) deque([]) 1
# deque(['C', 'V']) deque(['L']) 1
# deque(['C', 'V']) deque(['D', 'R', 'B', 'N', 'P', 'B', 'J', 'N', 'D']) 2
# deque([]) deque(['D', 'R', 'B', 'N', 'P', 'B', 'J', 'N', 'D', 'C', 'V']) 2
# deque(['F', 'F', 'J', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'R', 'H', 'W', 'M', 'C', 'G']) deque(['V', 'R', 'Q', 'B', 'V', 'L']) 4
# deque(['F', 'F', 'J', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'R', 'H']) deque(['V', 'R', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G']) 4
# deque(['D', 'R', 'B', 'N', 'P', 'B', 'J', 'N', 'D', 'C', 'V']) deque(['V', 'R', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G']) 1
# deque(['D', 'R', 'B', 'N', 'P', 'B', 'J', 'N', 'D', 'C']) deque(['V', 'R', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G', 'V']) 1
# deque(['V', 'R', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G', 'V']) deque(['F', 'F', 'J', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'R', 'H']) 1
# deque(['V', 'R', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G']) deque(['F', 'F', 'J', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'R', 'H', 'V']) 1
# deque(['F', 'F', 'J', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'R', 'H', 'V']) deque(['J', 'W', 'S', 'R']) 6
# deque(['F', 'F', 'J', 'L', 'Z', 'Q', 'G', 'D', 'M']) deque(['J', 'W', 'S', 'R', 'V', 'V', 'P', 'R', 'H', 'V']) 6
# deque(['L', 'Z', 'Z', 'R', 'Q', 'V', 'H']) deque([]) 7
# deque([]) deque(['L', 'Z', 'Z', 'R', 'Q', 'V', 'H']) 7
# deque(['V', 'R', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G']) deque(['C', 'D', 'J', 'P', 'T', 'D', 'P', 'W', 'H']) 8
# deque(['V', 'R']) deque(['C', 'D', 'J', 'P', 'T', 'D', 'P', 'W', 'H', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G']) 8
# deque(['J', 'W', 'S', 'R', 'V', 'V', 'P', 'R', 'H', 'V']) deque([]) 1
# deque(['J', 'W', 'S', 'R', 'V', 'V', 'P', 'R', 'H']) deque(['V']) 1
# deque(['L', 'Z', 'Z', 'R', 'Q', 'V', 'H']) deque(['J', 'W', 'S', 'R', 'V', 'V', 'P', 'R', 'H']) 1
# deque(['L', 'Z', 'Z', 'R', 'Q', 'V']) deque(['J', 'W', 'S', 'R', 'V', 'V', 'P', 'R', 'H', 'H']) 1
# deque(['J', 'W', 'S', 'R', 'V', 'V', 'P', 'R', 'H', 'H']) deque(['F', 'F', 'J', 'L', 'Z', 'Q', 'G', 'D', 'M']) 6
# deque(['J', 'W', 'S', 'R']) deque(['F', 'F', 'J', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'R', 'H', 'H']) 6
# deque(['J', 'W', 'S', 'R']) deque(['L']) 1
# deque(['J', 'W', 'S']) deque(['L', 'R']) 1
# deque(['D', 'R', 'B', 'N', 'P', 'B', 'J', 'N', 'D', 'C']) deque(['V', 'R']) 8
# deque(['D', 'R']) deque(['V', 'R', 'B', 'N', 'P', 'B', 'J', 'N', 'D', 'C']) 8
# deque(['V', 'R', 'B', 'N', 'P', 'B', 'J', 'N', 'D', 'C']) deque(['V']) 8
# deque(['V', 'R']) deque(['V', 'B', 'N', 'P', 'B', 'J', 'N', 'D', 'C']) 8
# deque(['J', 'W', 'S']) deque(['F', 'F', 'J', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'R', 'H', 'H']) 3
# deque([]) deque(['F', 'F', 'J', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'R', 'H', 'H', 'J', 'W', 'S']) 3
# deque(['L', 'Z', 'Z', 'R', 'Q', 'V']) deque(['C', 'D', 'J', 'P', 'T', 'D', 'P', 'W', 'H', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G']) 6
# deque([]) deque(['C', 'D', 'J', 'P', 'T', 'D', 'P', 'W', 'H', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G', 'L', 'Z', 'Z', 'R', 'Q', 'V']) 6
# deque(['F', 'F', 'J', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'R', 'H', 'H', 'J', 'W', 'S']) deque(['L', 'R']) 15
# deque(['F', 'F', 'J']) deque(['L', 'R', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'R', 'H', 'H', 'J', 'W', 'S']) 15
# deque(['C', 'D', 'J', 'P', 'T', 'D', 'P', 'W', 'H', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G', 'L', 'Z', 'Z', 'R', 'Q', 'V']) deque(['L', 'R', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'R', 'H', 'H', 'J', 'W', 'S']) 21
# deque(['C', 'D']) deque(['L', 'R', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'R', 'H', 'H', 'J', 'W', 'S', 'J', 'P', 'T', 'D', 'P', 'W', 'H', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G', 'L', 'Z', 'Z', 'R', 'Q', 'V']) 21
# deque(['V', 'B', 'N', 'P', 'B', 'J', 'N', 'D', 'C']) deque(['C', 'D']) 4
# deque(['V', 'B', 'N', 'P', 'B']) deque(['C', 'D', 'J', 'N', 'D', 'C']) 4
# deque(['C', 'D', 'J', 'N', 'D', 'C']) deque([]) 5
# deque(['C']) deque(['D', 'J', 'N', 'D', 'C']) 5
# deque(['V', 'B', 'N', 'P', 'B']) deque(['C']) 1
# deque(['V', 'B', 'N', 'P']) deque(['C', 'B']) 1
# deque(['V', 'R']) deque(['D', 'J', 'N', 'D', 'C']) 1
# deque(['V']) deque(['D', 'J', 'N', 'D', 'C', 'R']) 1
# deque(['V']) deque(['F', 'F', 'J']) 1
# deque([]) deque(['F', 'F', 'J', 'V']) 1
# deque(['D', 'R']) deque(['C', 'B']) 1
# deque(['D']) deque(['C', 'B', 'R']) 1
# deque(['D', 'J', 'N', 'D', 'C', 'R']) deque([]) 4
# deque(['D', 'J']) deque(['N', 'D', 'C', 'R']) 4
# deque(['L', 'R', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'R', 'H', 'H', 'J', 'W', 'S', 'J', 'P', 'T', 'D', 'P', 'W', 'H', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G', 'L', 'Z', 'Z', 'R', 'Q', 'V']) deque([]) 18
# deque(['L', 'R', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'R', 'H', 'H', 'J', 'W', 'S', 'J', 'P', 'T']) deque(['D', 'P', 'W', 'H', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G', 'L', 'Z', 'Z', 'R', 'Q', 'V']) 18
# deque(['D', 'J']) deque(['N', 'D', 'C', 'R']) 2
# deque([]) deque(['N', 'D', 'C', 'R', 'D', 'J']) 2
# deque(['N', 'D', 'C', 'R', 'D', 'J']) deque(['C', 'B', 'R']) 6
# deque([]) deque(['C', 'B', 'R', 'N', 'D', 'C', 'R', 'D', 'J']) 6
# deque(['F', 'F', 'J', 'V']) deque(['V', 'B', 'N', 'P']) 1
# deque(['F', 'F', 'J']) deque(['V', 'B', 'N', 'P', 'V']) 1
# deque(['L', 'R', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'R', 'H', 'H', 'J', 'W', 'S', 'J', 'P', 'T']) deque(['V', 'B', 'N', 'P', 'V']) 6
# deque(['L', 'R', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'R', 'H', 'H']) deque(['V', 'B', 'N', 'P', 'V', 'J', 'W', 'S', 'J', 'P', 'T']) 6
# deque(['F', 'F', 'J']) deque([]) 3
# deque([]) deque(['F', 'F', 'J']) 3
# deque(['F', 'F', 'J']) deque(['D', 'P', 'W', 'H', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G', 'L', 'Z', 'Z', 'R', 'Q', 'V']) 3
# deque([]) deque(['D', 'P', 'W', 'H', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G', 'L', 'Z', 'Z', 'R', 'Q', 'V', 'F', 'F', 'J']) 3
# deque(['D']) deque([]) 1
# deque([]) deque(['D']) 1
# deque(['C', 'B', 'R', 'N', 'D', 'C', 'R', 'D', 'J']) deque([]) 1
# deque(['C', 'B', 'R', 'N', 'D', 'C', 'R', 'D']) deque(['J']) 1
# deque(['V', 'B', 'N', 'P', 'V', 'J', 'W', 'S', 'J', 'P', 'T']) deque(['J']) 6
# deque(['V', 'B', 'N', 'P', 'V']) deque(['J', 'J', 'W', 'S', 'J', 'P', 'T']) 6
# deque(['J', 'J', 'W', 'S', 'J', 'P', 'T']) deque([]) 1
# deque(['J', 'J', 'W', 'S', 'J', 'P']) deque(['T']) 1
# deque(['D']) deque(['J', 'J', 'W', 'S', 'J', 'P']) 1
# deque([]) deque(['J', 'J', 'W', 'S', 'J', 'P', 'D']) 1
# deque(['C', 'B', 'R', 'N', 'D', 'C', 'R', 'D']) deque([]) 2
# deque(['C', 'B', 'R', 'N', 'D', 'C']) deque(['R', 'D']) 2
# deque(['L', 'R', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'R', 'H', 'H']) deque(['D', 'P', 'W', 'H', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G', 'L', 'Z', 'Z', 'R', 'Q', 'V', 'F', 'F', 'J']) 2
# deque(['L', 'R', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'R']) deque(['D', 'P', 'W', 'H', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G', 'L', 'Z', 'Z', 'R', 'Q', 'V', 'F', 'F', 'J', 'H', 'H']) 2
# deque(['D', 'P', 'W', 'H', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G', 'L', 'Z', 'Z', 'R', 'Q', 'V', 'F', 'F', 'J', 'H', 'H']) deque(['C', 'B', 'R', 'N', 'D', 'C']) 5
# deque(['D', 'P', 'W', 'H', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G', 'L', 'Z', 'Z', 'R', 'Q', 'V']) deque(['C', 'B', 'R', 'N', 'D', 'C', 'F', 'F', 'J', 'H', 'H']) 5
# deque(['D', 'P', 'W', 'H', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G', 'L', 'Z', 'Z', 'R', 'Q', 'V']) deque(['T']) 15
# deque(['D', 'P', 'W']) deque(['T', 'H', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G', 'L', 'Z', 'Z', 'R', 'Q', 'V']) 15
# deque(['T', 'H', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G', 'L', 'Z', 'Z', 'R', 'Q', 'V']) deque(['L', 'R', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'R']) 5
# deque(['T', 'H', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G', 'L']) deque(['L', 'R', 'L', 'Z', 'Q', 'G', 'D', 'M', 'V', 'V', 'P', 'R', 'Z', 'Z', 'R', 'Q', 'V']) 5
# deque(['C', 'B', 'R', 'N', 'D', 'C', 'F', 'F', 'J', 'H', 'H']) deque(['V', 'B', 'N', 'P', 'V']) 2
# deque(['C', 'B', 'R', 'N', 'D', 'C', 'F', 'F', 'J']) deque(['V', 'B', 'N', 'P', 'V', 'H', 'H']) 2
# deque(['C', 'B', 'R', 'N', 'D', 'C', 'F', 'F', 'J']) deque([]) 6
# deque(['C', 'B', 'R']) deque(['N', 'D', 'C', 'F', 'F', 'J']) 6
# deque(['R', 'D']) deque(['C', 'B', 'R']) 1
# deque(['R']) deque(['C', 'B', 'R', 'D']) 1
# deque(['J', 'J', 'W', 'S', 'J', 'P', 'D']) deque(['T', 'H', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G', 'L']) 6
# deque(['J']) deque(['T', 'H', 'Q', 'B', 'V', 'L', 'W', 'M', 'C', 'G', 'L', 'J', 'W', 'S', 'J', 'P', 'D']) 6
# deque(['C', 'B', 'R', 'D']) deque(['J']) 3
# deque(['C']) deque(['J', 'B', 'R', 'D']) 3
# deque(['D', 'P', 'W']) deque([]) 2
# deque(['D']) deque(['P', 'W']) 2
# VHJDDCWRD
